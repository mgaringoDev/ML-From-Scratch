# %% [markdown]
# # Introduction
#
# The following was inspired by the following articles
#
# - Medium
#     - How to build a Recurrent Neural Network in TensorFlow [[1]](https://medium.com/@erikhallstrm/hello-world-rnn-83cd7105b767)[[2]](https://medium.com/@erikhallstrm/tensorflow-rnn-api-2bb31821b185)[[3]](https://medium.com/@erikhallstrm/using-the-tensorflow-lstm-api-3-7-5f2b97ca6b73)[[4]](https://medium.com/@erikhallstrm/using-the-tensorflow-multilayered-lstm-api-f6e7da7bbe40)[[5]](https://medium.com/@erikhallstrm/using-the-dynamicrnn-api-in-tensorflow-7237aba7f7ea)[[6]](https://medium.com/@erikhallstrm/using-the-dropout-api-in-tensorflow-2b2e6561dfeb)
#     - [RNN example by Python](https://towardsdatascience.com/recurrent-neural-networks-by-example-in-python-ffd204f99470)
# - GitRepos
#     - [char-rnn-tensorflow](https://github.com/sherjilozair/char-rnn-tensorflow)
#     - [RNN](https://github.com/WillKoehrsen/recurrent-neural-networks/tree/master/notebooks)
#     - [KERAS for Humans](https://github.com/keras-team/keras/blob/master/examples/lstm_text_generation.py)
# - Kaggle Repos
#     - [Learn by example RNN/LSTM/GRU time series](https://www.kaggle.com/charel/learn-by-example-rnn-lstm-gru-time-series)
# - machinelearningmaster
#     - [How to Develop a Character-Based Neural Language Model in Keras](https://machinelearningmastery.com/develop-character-based-neural-language-model-keras/)
#     - [Adventures of machine learning](http://adventuresinmachinelearning.com/keras-lstm-tutorial/)
# -  Troubleshooting
#     - [Input size of the LSTM layer](https://github.com/keras-team/keras/issues/2045)

# %% [markdown]
# # Imports

# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

# %% [markdown]
# # Functions

# %% [markdown]
# ## Sample

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ## Epoch End

# %%
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %% [markdown]
# ## Read

# %%
def readData(FileDir):
    # Get the database from a list of characters that is found in the input.txt
    # should be simple plain text file
    data = open(FileDir, 'r').read() 
    return data

# %% [markdown]
# # Data

# %% [markdown]
# ## I/O

# %%
fileDir = 'data/rnn/input.txt'
text = readData(fileDir)

# %%
print('corpus length:', len(text))
# Out:
# corpus length: 4994

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 49

# %% [markdown]
# ## Cleaning

# %% [markdown]
# ### Formating

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 1652

# %% [markdown]
# ### Convert Text to Sequence
#
# The main purpose is to divide the entire abstract information into sentences with **n** number of words.  Where each word is a number which corresponds to the vocabulary.
#
# Our preprocessing is going to involve using a Tokenizer to convert the patents from sequences of words (strings) into sequences of integers.
#
# We will use a sequencing function to perform this task.  Where this function takes various parameters including a training length which is the number of words we will feed into the network as features with the next word the label. For example, if we set training_length = 50, then the model will take in 50 words as features and the 51st word as the label.
#
# For each abstract, we can make multiple training examples by slicing at different points. We can use the first 50 words as features with the 51st as a label, then the 2nd through 51st word as features and the 52nd as the label, then 3rd - 52nd with 53rd as label and so on. This gives us much more data to train on and the performance of the model is proportional to the amount of training data.

# %%
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %% [markdown]
# # Model Generation

# %% [markdown]
# This is where you can change LSTM to GRU or RNN.
#
# This is basically where you design your network.
#
# The rest of the code is just to clean the data in such a way that it can be places in here.
#
# The output of the data is sampled at each end of the epoch.

# %% [markdown]
# ## Multiple Layers

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape=(maxlen, len(chars))))
model.add(LSTM(128, input_shape=(maxlen, len(chars))))

model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
print(model.summary())
# Out:
# Build model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_10 (LSTM)               (None, 40, 128)           91136
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 128)               131584
# _________________________________________________________________
# dense_4 (Dense)              (None, 49)                6321
# =================================================================
# Total params: 229,041
# Trainable params: 229,041
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Single Layer

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
print(model.summary())
# Out:
# Build model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_12 (LSTM)               (None, 128)               91136
# _________________________________________________________________
# dense_5 (Dense)              (None, 49)                6321
# =================================================================
# Total params: 97,457
# Trainable params: 97,457
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # Training the RNN - LSTM

# %% [markdown]
# Split a the data into training and validation set and use one hot encoding.

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
np.shape(x)
# Out:
# (1652, 40, 49)

# %%
np.shape(y)
# Out:
# (1652, 49)

# %% [markdown]
# ## Training Single Layer

# %%
model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Epoch 1/60
# 1652/1652 [==============================] - 3s 2ms/step - loss: 3.3988
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: " took for granted everything we had
# As i"
#  took for granted everything we had
# As i                                                                                                                                                                                                                                                                                                                                                                            e
# ----- diversity: 0.5
# ----- Generating with seed: " took for granted everything we had
# As i"
#  took for granted everything we had
# As i      oe to e l  e    ei eoe e  i  u   t       u        d   h       e         o      rt   e   ybl  h   dteoi  eyt   i     l   o
#     ee  e oe   e  dio e       oe
#  e e olt  tr o      t e  e n        e e    o      y e    e       ie e oei   e ai eo e h   e    io e  t a e   'te  uyt   te    s   e   o  e  e     e   e  ey         t      n       deo e  dt      en      o    t  h     l e  i ite  o  r  tfe
# ----- diversity: 1.0
# ----- Generating with seed: " took for granted everything we had
# As i"
#  took for granted everything we had
# As i  afoagoo'w e
#  dttti  od o uoasoviea hgra r  fb gnsd yI  d essio bf  els o  y ooemIo P ld wykehegewne g    o'ds  ow e oirrtw tr  i hm  aIeth ee  soi  eotalndb n eaeee bmth'p
# m
#  e l  le
# oeai ns  im
# i  wnn i  leiibe l  oeo  og 'oy pr yoeiO r b iee ermrdet  ne iwG it m
# e oOm n l y
# eip i n   boao du  a ineaa
# aetm
#  fe de d a eI  yo'e iIShw
# t bvfi vbtoi
# iI igi u  akaunty e  e  op
#   ogwine e hown e
# (S
# ----- diversity: 1.2
# ----- Generating with seed: " took for granted everything we had
# As i"
#  took for granted everything we had
# As itv m  t n
# I wt t'yweoleAe ueeie  'nrh ngl
# i (ae h  HyooseoOii
# h   yb emybmivn
#  iaw  ry ul lemc wg' mnoesyhssObe?immttso trhivdnoetvWur  Aihrry I hy'
# f sImtf ayovv?A  (hnpe
# eomoowoe ba Wti Ti reeWesut d  (int  y tfo oh ylio 'youeetri  e
# ghelr
#
# o(ebgoto tagmfa '' Tt
# dIb,e)soSOet
# wdio ' tmylrn o
# emt W
# tvO' ri o
#  ngrmrn
# oeoeyr  hyode aooaWh   c yyg
# eWar  u t  S  nak emr layk   lpe oyoo y  eAe(Nubso
# Epoch 2/60
# 1652/1652 [==============================] - 1s 881us/step - loss: 3.0400
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: " that no one else knows
# I'll let you in "
#  that no one else knows
# I'll let you in ooooooooe ooon oeeooee oooo aoo o e oe oe ooee ooooo oon oeto ooonee ooe oe oe oo oe oeoe anoo e ooe ooo ooo oene ooooeo oouoooe soom oote oo oeoeoooo ooe oooo oooooin ooe oooooeo oeeosooe onoooo eooe o oeo oe oooe oooe oe oo  oebot ooe oe oe oae ieooooe o  oe e o oooe ose e io eo oo oooeooe ooe ooe te oooe oooe oooo oooaoooe o nieeoonooeoeoeooooooo oeooe oee ooome eooooooo oboe aeoooou e oone oeo
# ----- diversity: 0.5
# ----- Generating with seed: " that no one else knows
# I'll let you in "
#  that no one else knows
# I'll let you in oeoiw oanusloey t oyabwund ee n olio eoin fe o e lseleiadoeyoooyos niayoaoeoyb o srt eonhe s ien soeoolne ooobotooee tone  yoie oe la oeer ouunooemoooe eu tnsbnneu iowaoaml oe tn sit eoat seis e soope altos etsoolooobmmoovm abon ekaoae fus y inee teeon yelood ooebuoue W  Ihoe snnn i aon solbnerneouw aasoe ie odaesooet uIobeyinnis s y oenoe oesoeuooIooneteheebaoeoeeooue tyooos ninlyoi
# eoohdu
# sue  a
# ----- diversity: 1.0
# ----- Generating with seed: " that no one else knows
# I'll let you in "
#  that no one else knows
# I'll let you in w
# eit ntberIk veeennn ysrvoat eatehia teofAte oootooosielebassynyibones'yIoaeo  neaaout aawn Ine hbewiolpo','
# kfiund d orynouestyooilhyhes Pwaeao aoouatthmiedeaob tnbutfsueoeeihr no enabiiIbedhwef InyonWahIngma buwuvirto IeIwspuou tIrnt seatuhowb  'vebntnemn  bsld h ab doaeiftofylou
# Pahyberye oo
# fbmokheiwmlvotfonsbbfshoing gmy Ohfn bftaW et,mabp oityv(iesoot iofevowiouevsot uowniIIb beodyveo lw nn
# ----- diversity: 1.2
# ----- Generating with seed: " that no one else knows
# I'll let you in "
#  that no one else knows
# I'll let you in o vlnniopuout dlnviuvtmndouvtdonyentbin z yToptvi ae oeikn eognume
# ionIyp  eipwoypoesW,o tmyeskmltsopdens eIobtokndy'weslsoidbfoy'oupb
# inItesindWdbg bkyuoopufwBbyn uNiybIoimo afinsawided  os  omndavieeefsOdneeainnie
# e oPkhi fke apeaeootsca
#  nS's oir nu'AawIrdepmt
# itoyou oleownlwtIatkm,etgtfnifsisIesnuoancrmdAiawmifnn btffI'YfeIae
#  mg,emvaedu fswfumlngnoNopdiiha'oyp bosfgrboumif(hnirt'eWybawIosaef
# Epoch 3/60
# 1652/1652 [==============================] - 1s 886us/step - loss: 2.8459
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "hat some how
# You will understand the way"
# hat some how
# You will understand the way yo   e t a   o  a  e t  o   e  oe  oe  oe  o    o  oe e  a  o   e  oe  ou  ou  oe the s  oe t  o  oe  oe  oe  oe  oe  o   ou t  o  oe t  o   oo  e  ou  ou t  o  oe  o   ou  ou t  ou  ou  ou you  oe  oe  o  ou  a   o  oo  oe  oo  a  ou  oe  ou  oe  ou  e  ou  ou  e  o  oe  e  a   oe  ou t a   o   ou t  o   e  ou s  oe you  oe oo   o  ao  oe  oe  oe  o  e  oe  oe t    o  oe t  e  oe  oe  ou  o   ou
# ----- diversity: 0.5
# ----- Generating with seed: "hat some how
# You will understand the way"
# hat some how
# You will understand the way t n     at boun t t y  f  e  eo a n o   o    e  e  ou  ou t an  ma a     e  a  solt me t    n  t fe  oe you th  oe yne ooe  oa e o I  e tiwd  o s yo  o  e fo  oh t in p he i  oe st it  e d i  he lo kel s  he  t you w  s at  oe t t oe s no l  a  oe ale  oo  oin oe ee lo s e  oea oe  o t be  oe ot te s  ou t  o t a we  oa  ou yoe  e  s  en t  a  e  e t  a  Ie he  ye  alb al g be tou  e re o  l yon
# ----- diversity: 1.0
# ----- Generating with seed: "hat some how
# You will understand the way"
# hat some how
# You will understand the way nh ?a Ig y ngrDowlone manhd on me' tnht oheY o
#  aaTiy mat
# udh anoSi y d d u sewoa fIrt mns afot yow wyou tiy tt d kin y'r
# veot yr ou lyapthiuanot ge ait oonfje ai kh  eeawl fe I won
# Ie oA nt vebs oe boe it f  bo ts    b hein asN 'ei e' tt Ione
# hed ata he eo kuo hyin d mm n  'l a aeoplwnegtah  ho't lo s  n  in om bon I yy oo'moe we er yn roba
# fh 'noa ui  y ehits oeebi t thu  oorIe kp Befsea fa bw
# ----- diversity: 1.2
# ----- Generating with seed: "hat some how
# You will understand the way"
# hat some how
# You will understand the way of yboww fe'lod o j bSkmu Iy  wfm teuvDd ? iSt e
# eait taIj og boghau d  n teome e  snsuvsn
# aooh mkd wen
# atdoeisps  gadnt?e'  kts oot ye  hlOyll homybbn'hwn foW  Iog yoe woeh
#  be'liw d kHnOIeayiwhevsus t  weB o l iw u  ol
#  bopabate
# ow byoMo
# e r
# auhnI mets oh  Nhnf dwe loi as,n I e'doI te i igeheasfo' souka op  o I fue nem rewhr inutS inhset I  fv  te  onlthW st d ib  bIoa bees be
# sg  tl  w uit w
# Epoch 4/60
# 1652/1652 [==============================] - 2s 912us/step - loss: 2.5494
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "our own)
# And all of the things I've been"
# our own)
# And all of the things I've been you t yow t you t you t yow the the yowe you t yow t yow t yow yow the the the the t yow t yo t yow the the t yow the wat we dow the the the we you thy yow t yoy be the t the t you t wot yow the the the the the the t yow the you the w yow the we you the the yow the the the t yow t yow t yoy yoy you t yow t yoe the the yowat you the yow yow the the the the the yow the the the the the the the the t
# ----- diversity: 0.5
# ----- Generating with seed: "our own)
# And all of the things I've been"
# our own)
# And all of the things I've been we the ne yow moy
# d
# elyowit yoo te dow ne you the t t t thy s thy me thr the dyye you wout you be y yoe  e w t de yle merhid yof t'y be t das we y yoyoyody doe t wet whan  me be the win wowhe me d yop t you the thy t s the oi y you yo t yoby we y wi
# A e sithe your sow th bo t ye you y way you s yo e mi t you wiw t yyme dowit yoy we the thor me yo wy ay by wo le de wor y in wou the ther l'yoyou s
# ----- diversity: 1.0
# ----- Generating with seed: "our own)
# And all of the things I've been"
# our own)
# And all of the things I've beenhohls wiay nintset yathbe slait we yot dhwnts
# dty bobow
# atlwlwl thye ifpter ykis slyot?me yow uhstbavh  hesd norwy yoth d un tldhay
# flatwanikidl w ae me
# yoe t
# for nleot yaaelly e'
# Bwhan b' f ne yow d yowhehy'weeTas ts lin
# owt Flskin  patWar yr y wytOi litomeps mw Ioe layydcisw me Ill dyve a'T fin ake shAnir wlyeo ow s yoknht aoi oboroslm ghawd you  ue s me mT then dy byiotl yeit yofoy yowe y yob
# ----- diversity: 1.2
# ----- Generating with seed: "our own)
# And all of the things I've been"
# our own)
# And all of the things I've beenine meliAt'snwn0va'0of du'h
# rt
# h  tom hor'thw n0 yowoI d int thelneeb ifefotbd mes ySlplyval tnm
# wanh toy  t ehadyy'lf ame dwy gfs tdbi'd totevihone gen
# sWe bet yoaeruhwythmyl
# ome be'nyey(s yfmei Imaiofld
# oeat fknn
# ffy ou mt m tewar'sSalouone mily That b y s deldofe To ln y'tgintly yorttttB, t dreisubjnvow lnOhm siuy
# Wie me min yts' yeAnsda fo'v myone y wayofd  t oyjunf yhe
#
# 0r
# yhle y Tyesdms'boi
# Epoch 5/60
# 1652/1652 [==============================] - 1s 892us/step - loss: 2.3041
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "ow (feeling right now)
# Baby somehow I w"
# ow (feeling right now)
# Baby somehow I wou thou the ther our our our our oou the ther oor aour aou the the ther our oor ther our oor the ther our our oor I'llle our our oor sou ther ourther ourther oor sowather ourthou ther our oor aou ther ou the the ther our ou ther our oor ther our yourthang our our oor ther our our aourther our our oor ther ourthang our oou ther oor aou the the ther our oor ther aour our ourthang ay our oor our you
# ----- diversity: 0.5
# ----- Generating with seed: "ow (feeling right now)
# Baby somehow I w"
# ow (feeling right now)
# Baby somehow I wour oou thang for thang her a loun aow the our mer youls me oor no fout le bou
# bourthang the the ther hon hour ooe sone oourdour for aour oor your aowhen le the thehe the than oorr ou the ahe wou tou the thend ou the dourthan s thane me ber al she ou therther our ou won sowr our op than s ther ouraathour allinather ou than
# Ohels your
# Sou the ther Foithethourthonf
# Oou the thathone your oorr oor I'n
# ----- diversity: 1.0
# ----- Generating with seed: "ow (feeling right now)
# Baby somehow I w"
# ow (feeling right now)
# Baby somehow I wad yoWrrooe oT th n aowat ghankame therg woufOhend ayrnhthe dhugyIthone
# kime yoholety arou Moe t
# everwfee hinbrthr tearsinu yourtheny au ka has s thane ouos
# meyanldnlfthayoonlsl jI p tna wlaldyoundaslrofor tma bsjOhang ve 0ir tes boutbd aoiel your
# Ios aathdrhasbyomey your
# Od bine Homn
# rhe ouu ml t den borrnayrfay
# Tave thoe
# hareAlloffayoDon nawalnowaspsayour IwnTame aa s enbwahe
# Wof thy tale
# Iaewou
# ----- diversity: 1.2
# ----- Generating with seed: "ow (feeling right now)
# Baby somehow I w"
# ow (feeling right now)
# Baby somehow I wur yog mm uourm paYe ooeO fouriheryopslOmeldofAbmebowu Ilelromyb or'mis ay ay Whe al
# efs Ofy (at,infeIthueig nmd(Wned'the bhpr you yayr dofon yig rr
# Whal 'uu
# ounr
#
# oip out uawatonat karbFnve yo  bae, anatike
# oontaOigsyyinhlesWayelsHayt'yhe luinebay oor yheudat natke thf
# soentinebyonobynh goins fhave os sof the k whr thsrdyWinu Iyluthengs Youroaplhyo
# brbou youSonltlot bWh betntvea onfrhi doyeadhinl
# Epoch 6/60
# 1652/1652 [==============================] - 1s 832us/step - loss: 2.1222
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "d I'd let my mind drift so far away
# You "
# d I'd let my mind drift so far away
# You thang the the the the bo you the the the the the the thang all thang ou bope ou the bop be you thang ou the the bo you the the the be you the ther ou the be you the the bomebody you the the the be you thang ou the the the the boou
# And you the bomeboplline all the the the the the the the thang ou
# I'lling ou the be you thang thang ou the the boalline all the bo you the the the bou the the be you the
# ----- diversity: 0.5
# ----- Generating with seed: "d I'd let my mind drift so far away
# You "
# d I'd let my mind drift so far away
# You thing ou s the s ou then  of the lone
# Aodl and yon the bomeb boing alling you be your
# And dowithing
#  he be you line s le yow be for I'ver Iyou le be in  all ou tha be layow
# And I'll all af owing all I'lle oor
# Sod be win s your I you
# and ou lethan I'll alling ne allely for
# What ss no  al the boab I'lle you
# And the be you tha thal woe bone ing oalle I'llt yourt you the sod the done hou s do you bo
# ----- diversity: 1.0
# ----- Generating with seed: "d I'd let my mind drift so far away
# You "
# d I'd let my mind drift so far away
# You beliNadouig
#  ates
# jh'
#
# loI
# ourbeles thme  kour s ny
# wadin
# dha  ou bor thang tlabyndy ne all ine
# Oou
# Wnds Aweala'hes
# Womebhgueg
# grhIs deef aurSoue bouy oavb wfend Bis dur do
# Ias I fow alls oone
# ine
# Sime
# Ameowhing sale na s a  fy b wl yoult lobdbomadoelt daw
# An ole ooe
# I''l wothds thee
# SourabgAebedhesy Iingr
# Soe the by thad uaes
# Fin  ofelfyoFn
# ooel
# 'l lawling bo
# il I mer
# Tat daneal f  e keodeave sh
# ----- diversity: 1.2
# ----- Generating with seed: "d I'd let my mind drift so far away
# You "
# d I'd let my mind drift so far away
# You thy I'D your
# Andodoeingd I'gi wheat you
# Wha s'be ye ine' thyou P ou thYos n?ofI
# Ooves snbus tallaame I'lelsi
# A Ifouing
# fheaywsebothI'rwoIy
# I'llls ple
# foYl dstlind
# noesyI0eblkmlIwheyoN
# Ihis aydhayoe bouranI Bed
# Iyheayaey I'loI'le I'lr
# Aiy in sw hon beve
#  'la sve
#
#  ditis bowoceg yopr s y
# Whl s aftem'l lhfs
# ayhuano
# an no a
# ehve ofer soe m'
# le afsovit
# pods sle yoh?dyFwe doe IkOfra At s't lit'l slelboe
# Epoch 7/60
# 1652/1652 [==============================] - 1s 834us/step - loss: 1.9346
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "tle world of our own
# I'll tell you thing"
# tle world of our own
# I'll tell you thing oing thing wing thing wing thing withing ou thing thing oin s ine hing thing thing wing thing thing oing the thing thing thing thing wing thing wing the door in  oing thing thing oing thing wing thing thing wing tine thing thing ou thing thing thing thing thing wing thing oing ou thing tine wine hing thing thing thing thing thing thing thing wing thing thing wing thing wing thing me hing wing thi
# ----- diversity: 0.5
# ----- Generating with seed: "tle world of our own
# I'll tell you thing"
# tle world of our own
# I'll tell you thing t me thend oing wing teing me you thang thing oit ing wit s wing thing thing tin ou ling thin  of thing win s for in whine me thing oithing wing wine I's a line thing thing oo in the be yo it t ne alt t t tine me doof
# ine ne mend wine sine thline hin  oing you thing thay aone hing  ap ring thing wine oo thing ou thin s ife thing oit ine s in  oing wing the din I've bely me lithat you thing thing
# ----- diversity: 1.0
# ----- Generating with seed: "tle world of our own
# I'll tell you thing"
# tle world of our own
# I'll tell you thing wiv relsayon ouhwighing thingnw belithany whit e
# Wnibe thu tkingl ee bor kithers? lifstwing withe srekit meybe eent aing t mine sime I'w  ofethap ime A thrrnin'tdop time
# Sou
# me  outta le fe ait tihy hot whe 'tiil out ing hin s t yemiy yhn bo cat keforebe dint kig  lot meT ming win inethin
# c m s apy nin s you lithat yon
# hor iniphend
# p'tssing for be've you teds kit ine withm merals you
# Woing pis me
# ----- diversity: 1.2
# ----- Generating with seed: "tle world of our own
# I'll tell you thing"
# tle world of our own
# I'll tell you thing
#
# ou
# dookle tlel ofet oult as
# fyo  jor oit the you thin ths pofowhingaw se ffoy
# he gitles ooethinikoneve aine sn siven Ine ein n iug sen fou an fin
# 'sW
# Mohlvn I taeliow me ses bithines'plI dof ourypyfumy ny hithe ingfofy vas ive sooithgn bon
# sli ffmt aahe  ie rame oorowine pooibishorbdo lathingont
# Whithifwine doye moveeweeps mpi ha yoy beamy y'ri fo0 boeldin thr le liaya
# or
# ife fop fout
# aheelrt
# In
# Epoch 8/60
# 1652/1652 [==============================] - 1s 906us/step - loss: 1.7568
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "new
# What am I doing without you?
# I'm onl"
# new
# What am I doing without you?
# I'm onl ou then I me ane ou the than s me ale an s ne ane ou the than s me now the thand wine and alline ou the thon s me ane alling ou than s me s me hou things I've an s allithou
# Whan s me ane ane ou the than s me all ou the than s me ou the than s me I've an s me an  ou the the than s now the the then s methand withan s me all ou than s me ou than s me an wan s me ame ou the than s me ine and ou the t
# ----- diversity: 0.5
# ----- Generating with seed: "new
# What am I doing without you?
# I'm onl"
# new
# What am I doing without you?
# I'm onl our owe
# Oha then oue an s me homebeby you? ng he thon s me wan ou thal n sher owe ou than I wou t meb I've and ou thing withing hot me ame and ou that alling ou an I me ane the the thon
# And dowr
# Ohhand ou then our
# And wat an  ou dowithand your ound
# On' hithang ou
# Sou?t you than owead of an our I meas now an owithants me an wans dowing at ane wine e't bee be wat an alling ou
# And hit things you tha
# ----- diversity: 1.0
# ----- Generating with seed: "new
# What am I doing without you?
# I'm onl"
# new
# What am I doing without you?
# I'm onl ho is wurt
# an  ou
# I'vy Whings foptBe
# Ihin aywagn
# Gu'
# Auow sou? an whing hinhs I'b newind we thant nm fan I m fet moa bop thI nip thts s bopn
# And Ie  ain s kithe anen chan y fens
# Whanes ameatsyNof
# And mes Iever I'? oiug t line your ham fy me limg anwa w y uong
# h0nnwS
# Whan  hithes ou litg ing oure
# Dou d
# I'll ou tomebe'y atlings I's ne 'll  elmesseig the
# Souabine' that (our
# out me inl or t nte ouve
# ----- diversity: 1.2
# ----- Generating with seed: "new
# What am I doing without you?
# I'm onl"
# new
# What am I doing without you?
# I'm onl her I'k withowns
# Sot ass whon
# W ahe mr min's Yoaflr motha
# Sofe'n ow a
# Sot bow al oakas II'ln waen Ium fon
# I BhybysuWelSI vet ing
# n yin sene your
# Sous
# And susp lon g ifd
#  ma litg wass shen
# i
# joninhthab s m, y mep maveI I'vel I so
# ?an me he I wjeFt
# ohe s anw  amenelns Ou boWh
# 0hos
# Somethit Yaes I'l ans tnos
# anthls
# Whane ther om bomebaminw
# ayl ou t t tmts
# ihe
# hon
# Buve as a av a ethou ahwhin s ouen
# Epoch 9/60
# 1652/1652 [==============================] - 2s 973us/step - loss: 1.6010
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "dy wants you
# Baby open the door
# Don't yo"
# dy wants you
# Baby open the door
# Don't you the dome
# And our our oor domebody ne door
# And wine oor I'me allees our our our our our our oor
# And me allithe domebody for some
# And me home
# And me home
# And wat a me me dome
# And our oor
# And domebody me dome
# And allithe done
# And me home
# Whand mebedyour our oor
# And ways me me me me aome
# And wat aed ofe domebody fores your
# And me hone home hone home our our our our oor
# And me hone
# Whand ou
# I'me ale
# ----- diversity: 0.5
# ----- Generating with seed: "dy wants you
# Baby open the door
# Don't yo"
# dy wants you
# Baby open the door
# Don't your
# Whan wor domebymy me aope
# I'll aeleone me domebyour
# Ooh me dowr
# Whe your
# Ohe e me wae oof
# Whine mes ale oit ou bomebody na door
# And I'm doon
# se keame Iomebopy aleerays mer oop
# And ofe somes as aod ou thes Iomebebyour
# The dome
# And allithe doe seys our oo
#
# Whan I'll oop
# Somebody fores we sooh
#
# hone hone alle ke me allithe dour
# And ouras mofer owe
# And oe saodo
# And allaysuthe bomebody king was oor
#
# ----- diversity: 1.0
# ----- Generating with seed: "dy wants you
# Baby open the door
# Don't yo"
# dy wants you
# Baby open the door
# Don't yomrboan aowa
# Awd
# I'l veruome hor boug
# (ne meou feln
# Whad ker I'laIadalkoing we sailo
# Goel
# Wh,  ou says mayou
# Pame
# o
# p
# Whrrg
# Oh
# p dokine ple seour going alle
# Hoon o gheits too your
# Arhe sopire jung me out oor
# Oralige me going ue some ay mekeyour
# Whets adlifer ine oned
# and wamwsre
# Wersabow ine some
# I'llwithe
# Buddone dove domebomy noou
# Dode way no oin
# ourn plraI vehan ouldaveave wome I's Dane I've ne
# ----- diversity: 1.2
# ----- Generating with seed: "dy wants you
# Baby open the door
# Don't yo"
# dy wants you
# Baby open the door
# Don't yoult
# Tne kima p se Iai ar nersi
# uo,ryonld'd ogo love Gomet linet
# Whan tvisglwige or mereldyomure ni gomes omebebupt dhtr
# O'lllline me hap oredyswhing
# Oovas tet eesadabourlithimet yom betimesays taetalem Iom bewny
# ju nevePwiP Hers ou gowi
# DSel ne kooi
# Som youvb
# wou ayou in Iar Iemude eaneaabe
# aowathals ag owals mer noPes Ifdrin Nuesaigow
# ght bamat foay yourliyI meIdsed opsie I'verplys Nor ooyhtrgn I
# Epoch 10/60
# 1652/1652 [==============================] - 1s 835us/step - loss: 1.4288
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "
# Somebody needs you like never before
# So"
#
# Somebody needs you like never before
# Somebody ne bebebeby ou then s mebebebybebebeby ou thing wine mes bebebobebody ne bebebeby me bebebobebobebody ne bebebeby omebeby omebed bebebeby me bebebebebebeby me bebebeby olet you t me than s mebody me bebebody me beby ou t let you t me mebebybebebeby me bebebody me bebebeby me bebebobebybebebeby me bebebobebody ne bebebeby me bebeby omebeby me bebebody me bebebeby me bebebobebodybebebeby ou t
# ----- diversity: 0.5
# ----- Generating with seed: "
# Somebody needs you like never before
# So"
#
# Somebody needs you like never before
# Somebody all the t me s me  ou t me than s me bebebeby ne bebebopebes domebeby ou t tee you t in s let you t me mebe mebeby me s me wine dop bonet you t you t ne all out you t me the beby ne  me than s meve all pe le fouet in want ne outs pet mebebybybebeby me bean jurt wat aus bep beby owine domebody kene done sene ould yomebody me beby omebed boaebeby me our I mebody me bewaby me bebebebebebybed b
# ----- diversity: 1.0
# ----- Generating with seed: "
# Somebody needs you like never before
# So"
#
# Somebody needs you like never before
# Sony wf an I ver bem bep bop boneve  op'bebobybet bet lit ne beve bebebedking the ne op meby yourne mebow you t methine me ds feth ke't youss beo t me an tuanas me one hines ne? lerase I's s me thm sebe s you an l me'b been alle beve leine ile ler I mebld ou t mebe Mabebykway mn mer doSoo bomy hine od ae was d mer faun bele kioe bet I bybeb pe al s be len buw bef domebobebobeboFe kingbo0lline nebe
# N
# ----- diversity: 1.2
# ----- Generating with seed: "
# Somebody needs you like never before
# So"
#
# Somebody needs you like never before
# Some
# abljprnendodyonet nelelle leo ldou dou a ther s tels there  hortbome
#  jp bea0s beaebebiw yom d your s mebodybysomebebddys featrep da eain buin dume
# Sowed  jneg levendk0lels tho n mebomebop bed
# ave Siuet sefe(sn jurt you things (odothin's fuse domebobyblle Iosoonr wom dpln thrr wulle your omebsmee kigeine wonig dy'me  lomele'tapbo
# Yad baby kyoull akisas ah fer Ooh bebydely sed aen horep my
# Thrl
# Epoch 11/60
# 1652/1652 [==============================] - 1s 877us/step - loss: 1.2984
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "t I've taken
# Was a stop too late
# Now I'm"
# t I've taken
# Was a stop too late
# Now I'm doe the thon
# And ou thouthe thouthe thon
# And ou thing without you the thouthe wot tome
# Oo ou thouthe wot me me dowr
# And ou
# Somebody ne thonts you the thon
# And I've beou the thon
# And for dow
#
# ohethout you the thouthe wot me me dow
#
# And ou the thon
# And ou thouthe wot dome
# Ohe ne ou thouts you the thon
# And ou thouthe wot me ou thon
# And I've beang tht thouthe thouthe thon
# And ou thouthe wot me hou
# So
# ----- diversity: 0.5
# ----- Generating with seed: "t I've taken
# Was a stop too late
# Now I'm"
# t I've taken
# Was a stop too late
# Now I'm bod dowe
# Ohe s ou thing we
# Oh, alwe
# I've the thon
# And me ou loor
# And plt let me ou me me bome
# What ou me no on wht you thing
# the the thon
# And I've bowe
# I'l e me me ale the dowf
# And that ow the thouthe bot bet you thonts you
# Sowitht thouthe thof
# Ang for tha t out you the thon
# And do ooe
# What im I s bet you the thouthings e me ou doof
# And ne wn
# And me ou dowithou
# Oh that ne wathout you thouthe thon
# ----- diversity: 1.0
# ----- Generating with seed: "t I've taken
# Was a stop too late
# Now I'm"
# t I've taken
# Was a stop too late
# Now I'me
# Whan ow thnt amtI kike he lit
# When ou t ou
# And of
# Ands you lise do foons ou puou
#  ot oog trthouthe me ke w tle thoe neens howt
# homelhor now bedn oa lithduthe me ouedh I's iegsithand wets kithing
# on
# 0o doulat me thort wiggt your owr
# Oh thts ope
# I's you
# Somebody king we se you
# Somebody fenghtswighout you
# Sod botve toth
# I kt fopk
# ohe hes no ome
# One (om bom dow
#
# hangine rp I mebedne (on done Sop th
# ----- diversity: 1.2
# ----- Generating with seed: "t I've taken
# Was a stop too late
# Now I'm"
# t I've taken
# Was a stop too late
# Now I'm on't ing
# gf leow
# you?
# ont owises doe bod
# BuPs been you hine
# I'l ufer kou's yoe
# Sone on ait pevighouh
# Whr zow
# And wu me ke
# or I me wo e you
# op satha(duwI
# sallitut yop?in kngtone wam I wat ee eede na ne ay u know
# Ang  ep ke'ma you t om ay your wonflen semnY Yom that im wo nu wetsa kowh
# urlithe the togrg
# ne ou beangner no
# wA
# the pet sekutBr0 ow your own
# Aha kave trap non terle Ie kin t I Fon
# Mhise
# Epoch 12/60
# 1652/1652 [==============================] - 1s 828us/step - loss: 1.1383
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "mebody wants your love
# Baby open the doo"
# mebody wants your love
# Baby open the door
# And I'll the thon
# And I'll the time I've bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop b
# ----- diversity: 0.5
# ----- Generating with seed: "mebody wants your love
# Baby open the doo"
# mebody wants your love
# Baby open the dooi
# And for sume
# Whan Ig or door
# And I'll t lit the bowe
# And all of things I'll the time I've bonn
# And I'll at at at ing and win' I've bean and I'l se Iou
# Paby ne don't you t in s you bowithe things you t me me
# Bud dop le some
# And I've bopn
# And I'll the tin  ow t me I've beand time jued out he dop body in thing without you? I've benn I'll inght your out ame I'd and ou dowr
# And I'll the ting you
# Some
# ----- diversity: 1.0
# ----- Generating with seed: "mebody wants your love
# Baby open the doo"
# mebody wants your love
# Baby open the door
# Whe I nwrbyou
# Whas I verdiwit with k's ju dotidow
# The d my bee weaseysup you ling anl I's rng
# you? (on thin I dou ping
# Wha ind ay now
# I'le lees be in way ewse
# aom ala I gom I'me benking
# n0t a's I ge sime
# And Itve lithit fon
# I ll teee aldans man pave dowe
# And plen
# And Wit niwhou
# Somebopibhtnfkin w y mat I've de ning let alvight you t you t sithods your owe wants you lves
# And I've domn
# And alle do
# ----- diversity: 1.2
# ----- Generating with seed: "mebody wants your love
# Baby open the doo"
# mebody wants your love
# Baby open the door
# Ans mn I've bop bon't you? ay our owibe for sou dotp n whe
# Hads I babybnp yon nu you
# Othe mive tenIfored me amoi
# Sod
# Somebuby in mu thing
# nibe soow
# mn t
# rngsan way nuveid
#  fend wn
# Bur am wons Invw
# Doke you to i gt
# Oth tmu trme I'w llap pay
# Wha domet and ok
# Manlime dowc
# Whe tha enofor A bobybobegway I'vlibe Iwme
# An lou soif I wobydone
# Gamling fone 0and ava ont oupline Itset aning I'w 0le thi'gs
# Epoch 13/60
# 1652/1652 [==============================] - 1s 844us/step - loss: 1.0222
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "ll the things I've been looking for
# Have"
# ll the things I've been looking for
# Have bop bop bop bop bop bop bop bop bop bop bop bop bop bop bop body heeds you things I've beand always bean I merayou things I've bean le kine I've then s me hend all of the tht tht t me oo body hands you thing tha thout you thing without you the thou
# Somebody hants you thing without you thing tha thout you thing tha thout you thing without you thing without you thing tha thout you thing we se king
# ----- diversity: 0.5
# ----- Generating with seed: "ll the things I've been looking for
# Have"
# ll the things I've been looking for
# Have medd you the the tht than whethand wathat no othe the door
# And all of the thou
# I'll the the thon
# And all the thout you the thon
# I'll the tho thing tha thou
# And all of thing with ot t me me done out you the thm I've bean I seane than I m rathe tht ant her ou the tho the thout you thing the things s me ou me in mer oon
#
# Whe with pt you?
# And all of the tht t me oon
# Son't an at oo
# And I've beand
# Wha
# ----- diversity: 1.0
# ----- Generating with seed: "ll the things I've been looking for
# Have"
# ll the things I've been looking for
# Have aite wand
# adllaver sos'be oo thott you t as ing
# and se kay wa dowr
# And llwat ne me
# dape and we dangf
# Yfy Bu been I ketay on bovebody mand wh the be dyand withat e'm I ve kethan owe
# Habe wayb beonet lo' let now
# Whe the this Is ways the doupvoohe
# One I meb doerhing mo het nou w
# ythe like w'thn kime aathouts you th st
# hone oure'dn I'veray n auking our ibe mend
# Theadlne sone dlelop dat you ghen I'lll
# ----- diversity: 1.2
# ----- Generating with seed: "ll the things I've been looking for
# Have"
# ll the things I've been looking for
# Have mebywnylulet yourd
# Donst an hings
#  aln kighlith my Bod you? ou when ou daaia the outs thar igo m I've outse owe
# lutI thend
# 'm jurt you beas
# hight
# ght gowr
# And ne Itd lithnd
# And ay got
# Somight wurtdou
# Sodybnd youl
# Atwaye wh st not lea d of me hotr uts
# I'me kedne
# Somebody'llo king you
# P the thon
#
# hu hithout you?et you?
# rts the tamen mon pure the to N
# othl the t kine Ihmebopy
# I'n I's you
#
# owa y plo
# Epoch 14/60
# 1652/1652 [==============================] - 2s 936us/step - loss: 0.8752
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: " outside my door
# And all of the time I'm"
#  outside my door
# And all of the time I'm looking for somebody needs you ling thas no one out you t you things you ling the thon s you ling me allithe thouts you ling the thon
# s llet you?
# And all of the thou
# And all of the the thes your s me king the thon
# And door
# And all of the the thon
# And all of the thonts you t nithouthe door
# And all of the thonts you ling the thon
# And you t you then our oove doof
# And I've le keow
#
# hon that no ooe s
# ----- diversity: 0.5
# ----- Generating with seed: " outside my door
# And all of the time I'm"
#  outside my door
# And all of the time I'm loon
#
# Oh that me ones your s phong
# what am I song the without you?t yourt you?
# And all ofg
# the doof
# And all oft
# s me lios the now
#
# Oh the an mar keve thes you ling thes you
# le king the thon
# s you then sop the things you ling me as ats you
# Somebody pleas ou
# And yourt n't you t el ats your And lithings I've then soing you?
# And net lifer
# I'll theady mand you t you t on surng for som bop bop bop bop
# ----- diversity: 1.0
# ----- Generating with seed: " outside my door
# And all of the time I'm"
#  outside my door
# And all of the time I'm lk ke I's s ting thongs it he king
# on't yourt now
# Whe  sou
# But dom'thy know
# And wongs you be s op t your you?t kine me hanltses owale than nfoog
# I me liop things (our
# Whna youl
# Anl ous ing mave beofersnF'l tlany fo
# Sapl
# athe
# Som bop bop bod hets yop? me hens ng ourlgop by peels prar aod beaags astfant whom ou looking fur leve oneve loof
# asl jor
# And Dou t wn
# Au's likingighou
# Sodoalloy
# Thos I've be
# ----- diversity: 1.2
# ----- Generating with seed: " outside my door
# And all of the time I'm"
#  outside my door
# And all of the time I'm know I't llofy
# And ple I''l leop inghe I'llloam eod
# ing the dowr
# (on thas ke or lith
# out auatraveg you? pus you th n  op thas Iw and tllitht
# Yhor
# Wh't ave pn sinh tlingt you
#
# I'll ay ut antkon's you
# l wat s notave anghes sove
# mnt nohen whe
# doSale kaw
# Som sanithigg le ou wann ou t' sa)y uf I gof
# And witllitho hou lookino oor
# Have akeaye linegund ou me loon
# The hon't yove
#  I'nall enn whelekeYort t
# Epoch 15/60
# 1652/1652 [==============================] - 2s 915us/step - loss: 0.7688
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "n here outside my door
# And all of the ti"
# n here outside my door
# And all of the time I'm boon
# And ploat you be ng the t me allithe the things you t net me oon
# Somebody neets you t ing the thon
# And all the the things you t ing thouthe thongs ing me then sour
# And all of the t me oo
# hot authou
# Somebody ne the t me our
# And all the things you t ing tht t me am I mer oor
# And all the things I've beang the thont
# Oo llet you t ing t the thouthe thonts you ling the t me allithe things i
# ----- diversity: 0.5
# ----- Generating with seed: "n here outside my door
# And all of the ti"
# n here outside my door
# And all of the time I'm gots im I waybet trrs you tan the t out you?
# And all of the t me oo
# ang tht t me as wants you ling and whos I've been soing without you?
# And all the things 'l at you
# Somebody needs your ithout you tann wht aomebody needs you ling as I've been I'l let you t ing t me know
#
# on s the tom bots amn then s eray
# Ohan I boing without you?
# And all the t
# me
# and with you t ant me mand you?
# And all the
# ----- diversity: 1.0
# ----- Generating with seed: "n here outside my door
# And all of the ti"
# n here outside my door
# And all of the time I've thet ne one e dot a witht your I chingiwe
# Whan's for
# Tom If yout you?
# Bn a puat you
# Somebody nee kin
# ur hou my noe
# So bon bown
# Hayle out e payby yoras wa
# Somibeds ilg the t
# ing t me an was nw oor mop
#
# Ao liggt in'the boon
# And all of this is of do bligot
#
# ohe
#  am rod
# Atlleteay res of sou t ing aimhour you lingt
# Oow Yan a beas iow
#
# on d ing for
# gor gome
# on 'l ats ufort mive tots igh you lit
# ----- diversity: 1.2
# ----- Generating with seed: "n here outside my door
# And all of the ti"
# n here outside my door
# And all of the time I'm loory
# Yhan loig
# eld ou sayku
# Oo ise know
# tha ts alave my litt you tors our ilit thp tovt
# Somebodythe things for (ou't you no bor
# Bugn wh thop
# Ot set
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-57c5c77cfa2e> in <module>()
#       2           batch_size=128,
#       3           epochs=60,
# ----> 4           callbacks=[print_callback])
#
# ~\Anaconda2\envs\py36\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~\Anaconda2\envs\py36\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     215                         for l, o in zip(out_labels, val_outs):
#     216                             epoch_logs['val_' + l] = o
# --> 217         callbacks.on_epoch_end(epoch, epoch_logs)
#     218         if callback_model.stop_training:
#     219             break
#
# ~\Anaconda2\envs\py36\lib\site-packages\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#      77         logs = logs or {}
#      78         for callback in self.callbacks:
# ---> 79             callback.on_epoch_end(epoch, logs)
#      80
#      81     def on_batch_begin(self, batch, logs=None):
#
# <ipython-input-16-a56c0406bd90> in on_epoch_end(epoch, _)
#      19                 x_pred[0, t, char_indices[char]] = 1.
#      20
# ---> 21             preds = model.predict(x_pred, verbose=0)[0]
#      22             next_index = sample(preds, diversity)
#      23             next_char = indices_char[next_index]
#
# ~\Anaconda2\envs\py36\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# ~\Anaconda2\envs\py36\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# ~\Anaconda2\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~\Anaconda2\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~\Anaconda2\envs\py36\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Training Multilayer

# %%
# multiple LSTM layers
model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Epoch 1/60
# 1652/1652 [==============================] - 5s 3ms/step - loss: 3.3972
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "eave me alone
# Don't you turn out the lig"
# eave me alone
# Don't you turn out the lig  e    o                    o        o r     o    o              ao                     o                            o        n  o                       e    n    o                    o  a       n               t           n             o                                n         n   o       a   n                  no     o  n                      n                              n            o
# ----- diversity: 0.5
# ----- Generating with seed: "eave me alone
# Don't you turn out the lig"
# eave me alone
# Don't you turn out the lig d n rl   n  eo b o
#  ao ao   onwon o  loranon o  onofyos    waonot  n n    e   m ta       nan n oo hrotn  n o nwi s   ode  nba n enhnenoo oe n  o o   a o e   r  l ton  nts  s  sn
# o  gn o
# no o a     aotrh  we l u doo   n        nne
#  ton ntey f  odenn  oone   in o  e    donotnhsno eni  o e noo o   ofi neo e  yenea  o t n p e  non bu   ao n
#   oo   ha  he   'oho  nonro  e ooowsto  eo  n  no   nro h
# ----- diversity: 1.0
# ----- Generating with seed: "eave me alone
# Don't you turn out the lig"
# eave me alone
# Don't you turn out the lig lo
# Ynrlen ostanentmvwtotft inkbgo
# lnt 2l'rumnnna oaAnhaWslnhoadnw ootrIe etnl so
# uu
# na Autololoh lwepn
# dtood f
# er OpnobnG
# etta'roowaonk
# h  nngernA n
#  a wsa tkneepwtshwiaIo
# nat
# efnodtte
# bhnnmou dmsrn
# 0arkna
# em
# vo ninp   iy,na eeso   tn  moo  t o's avohdr e
# oab od
#  rhro otlemf f ve
# o s a  nb nnotdneeeaholh y tu an  uotokavisl
# mtso gaa v
# whn  p h aen aeogMoe
# no yt elseomelbw  0oCifh kn atu nnws d
# ----- diversity: 1.2
# ----- Generating with seed: "eave me alone
# Don't you turn out the lig"
# eave me alone
# Don't you turn out the lignhfenb
# wtt osohteeor
# uten ok kTt woint t bnenDmbp  upuentraIpnnaa gn
# nWr o oof orf
# a inidneeeoiatnmwnowpaalp?kd wdntybaseT h cdkhlueftv slt
#  noIn Pfnno)hIoniahki ndonvdrpeeysImb  ndroui
# Njan  viow appsbasmAel
# ninlmwtkbe mowP
# g 0   um eA oe n ew n oA'rt yovns
# r
# r?goola
# CD a
# snaea
# oPal bretYo
# (Ide i
# o   m nfb osn dullIaopdopmjpsmiwOiorbwt uow hz atofanaDyis ann
# ors  sh an f
# k IpW(d
#  insIdonooi0ts
# Epoch 2/60
# 1652/1652 [==============================] - 3s 2ms/step - loss: 3.0996
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "omebody wants you
# Somebody needs you
# Som"
# omebody wants you
# Somebody needs you
# Som         t                                    e           t         e           e        t                         a     t                e                  l                                    o                                    t           t                                                                             e
# ----- diversity: 0.5
# ----- Generating with seed: "omebody wants you
# Somebody needs you
# Som"
# omebody wants you
# Somebody needs you
# Somnb  s Inoa ewh     yoot t o t e o a te   n tt bte oh r ota     n s lnbe  oa   e   tohf   ew oiit   uaee  h  b  e  but t  i t n d dw  n ooo ds a o  a  eto n    re oug  mts  ame u lo  s  u  t lnl
# has an    ta t s  o oeiiu io  y a a ao    tt     w  t  u no  e  twt     d     eee    ee   sra ad
# on   h eoy        e  t  d w an     eo        t  dt tu ot  owio   a hedemS   la sol tme i mlr   oo utoanynat
# ----- diversity: 1.0
# ----- Generating with seed: "omebody wants you
# Somebody needs you
# Som"
# omebody wants you
# Somebody needs you
# Somg
# ih efhh   I vst s
#  g  oh wdl ae Seosotdfertmuf h'dotosoo esbm
#  o ul   iumt mas'ewwtaabe gfo aAN rI nannu Ipuevbtyim oaame eoe
# eldl  sto  l fwG oitaiublmlio'tlI we  f eh he ohh  r y(v e mhtbnhsm ys oetmt
#  aNmmr' rs doW Iun0 nbdr  'endem
# hsa ul keea  lheo o ufatStadbhauidyhufe ughmh eh sbdee mSo itmltsdyf ogf l s deoo  t Iaohy a
#  s
# a Igeotmus  geut df um dev?yl o
# i ltdWm auod ltay(oInolOybnh i
#
# ----- diversity: 1.2
# ----- Generating with seed: "omebody wants you
# Somebody needs you
# Som"
# omebody wants you
# Somebody needs you
# Somw Swoew tmfugyswwlyhi
# eweDksaMIiaaog kv'sf
# ws tSbunuiaonodeltitahollhumenTa eii hMiba analndnlhltIigl h Feb wili y
# om  pI nN gva  nbe uynuol ygh  A uaWIilI lvrwsntvdOuaHl imIafsuiyngaiwt
# o  FySgohu ouloobI
# do ultlagO Iu(rieba nA didbsseteh ptrp tmmmnyr0IaWt'ethhC eate v a'hdoanwult
# tf enpa dwy,eAvo ooezlteaiWno mymewdmIofyf t?tBe tb b
# ktoeurhidt Snuuonlm oslrom  toGyluphyooyouyso
# uemaaelnfsaN  s r
# Epoch 3/60
# 1652/1652 [==============================] - 4s 2ms/step - loss: 3.0937
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "ebody wants your love
# Baby open the door"
# ebody wants your love
# Baby open the doorn  e   oe   o  n e  n        o       o          e  o e    oe   n    e      e             o   n e   g          oo    n   a     n    n  e
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-253a8fe12c8f> in <module>()
#       3           batch_size=128,
#       4           epochs=60,
# ----> 5           callbacks=[print_callback])
#
# ~\Anaconda2\envs\py36\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~\Anaconda2\envs\py36\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     215                         for l, o in zip(out_labels, val_outs):
#     216                             epoch_logs['val_' + l] = o
# --> 217         callbacks.on_epoch_end(epoch, epoch_logs)
#     218         if callback_model.stop_training:
#     219             break
#
# ~\Anaconda2\envs\py36\lib\site-packages\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#      77         logs = logs or {}
#      78         for callback in self.callbacks:
# ---> 79             callback.on_epoch_end(epoch, logs)
#      80
#      81     def on_batch_begin(self, batch, logs=None):
#
# <ipython-input-16-a56c0406bd90> in on_epoch_end(epoch, _)
#      19                 x_pred[0, t, char_indices[char]] = 1.
#      20
# ---> 21             preds = model.predict(x_pred, verbose=0)[0]
#      22             next_index = sample(preds, diversity)
#      23             next_char = indices_char[next_index]
#
# ~\Anaconda2\envs\py36\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# ~\Anaconda2\envs\py36\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# ~\Anaconda2\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~\Anaconda2\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~\Anaconda2\envs\py36\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
