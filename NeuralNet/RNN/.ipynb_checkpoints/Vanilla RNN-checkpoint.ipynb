# %% [markdown]
# # Introduction
#
# This is my vanilla RNN implementation.  I got helped from Dr.Karpathy of the Stanford 231n profs.  The github implementation can be found [here](https://gist.github.com/karpathy/d4dee566867f8291f086).  And the original blog post based on this can be found [here](http://karpathy.github.io/2015/05/21/rnn-effectiveness/)

# %% [markdown]
# # Imports

# %%
import numpy as np

# %% [markdown]
# # I/O

# %% [markdown]
# - get the data from a text file
# - get the list of characters
# - get the length of the db and the vocabulary
# - associate each character with an index and vice versa

# %%
# Get the database from a list of characters that is found in the input.txt
# should be simple plain text file
data = open('input.txt', 'r').read()

# %%
# get the list of characters by first identifying the set() of characters and place them in a list()
# NOTE: set() function here creates an unorders collection with no duplicate elements
chars = list(set(data))

# %%
chars
# Out:
# ['\n',
#  ' ',
#  "'",
#  '-',
#  'A',
#  'F',
#  'I',
#  'H',
#  'N',
#  'P',
#  'S',
#  'T',
#  'W',
#  'Y',
#  'a',
#  'c',
#  'b',
#  'e',
#  'd',
#  'g',
#  'f',
#  'i',
#  'h',
#  'k',
#  'j',
#  'm',
#  'l',
#  'o',
#  'n',
#  'p',
#  's',
#  'r',
#  'u',
#  't',
#  'w',
#  'v',
#  'y']

# %%
# obtain the size of the data and the size of the vocabulary we have
data_size, vocab_size = len(data), len(chars)

# %%
print 'data has %d characters, %d unique.' % (data_size, vocab_size)
# Out:
# data has 1681 characters, 37 unique.

# %% [markdown]
# This is a text file so we know that there maybe 26 characters from the alphabet * 2 because of the capitals plus punctuations.  This seems reasonable so let us continue.

# %%
# enumerate the characters and give indices to them
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# %%
char_to_ix
# Out:
# {'\n': 0,
#  ' ': 1,
#  "'": 2,
#  '-': 3,
#  'A': 4,
#  'F': 5,
#  'H': 7,
#  'I': 6,
#  'N': 8,
#  'P': 9,
#  'S': 10,
#  'T': 11,
#  'W': 12,
#  'Y': 13,
#  'a': 14,
#  'b': 16,
#  'c': 15,
#  'd': 18,
#  'e': 17,
#  'f': 20,
#  'g': 19,
#  'h': 22,
#  'i': 21,
#  'j': 24,
#  'k': 23,
#  'l': 26,
#  'm': 25,
#  'n': 28,
#  'o': 27,
#  'p': 29,
#  'r': 31,
#  's': 30,
#  't': 33,
#  'u': 32,
#  'v': 35,
#  'w': 34,
#  'y': 36}

# %%
ix_to_char
# Out:
# {0: '\n',
#  1: ' ',
#  2: "'",
#  3: '-',
#  4: 'A',
#  5: 'F',
#  6: 'I',
#  7: 'H',
#  8: 'N',
#  9: 'P',
#  10: 'S',
#  11: 'T',
#  12: 'W',
#  13: 'Y',
#  14: 'a',
#  15: 'c',
#  16: 'b',
#  17: 'e',
#  18: 'd',
#  19: 'g',
#  20: 'f',
#  21: 'i',
#  22: 'h',
#  23: 'k',
#  24: 'j',
#  25: 'm',
#  26: 'l',
#  27: 'o',
#  28: 'n',
#  29: 'p',
#  30: 's',
#  31: 'r',
#  32: 'u',
#  33: 't',
#  34: 'w',
#  35: 'v',
#  36: 'y'}

# %% [markdown]
# # Parameters

# %% [markdown]
# ## HyperParameters

# %%
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# %% [markdown]
# ## Model Parameters

# %%
# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

# %% [markdown]
# # Functions

# %% [markdown]
# ## Loss

# %% [markdown]
# **Forward Pass**
# ![](https://i.imgur.com/qaJLCZK.png)

# %%
def lossFun(inputs, targets, hprev):
    """
    inputs,targets are both list of integers of size seq_length 
    hprev is [Hx1] array of initial hidden state
    returns the loss, gradients on model parameters, and last hidden state
    """
    # inits for forward pass
    # xs: input state
    # hs: hidden state
    # ys: output state
    # ps: propbability state
    xs, hs, ys, ps = {}, {}, {}, {}
    hs[-1] = np.copy(hprev)
    loss = 0

    # forward pass
    # t is the tick for all inputs in the sequence
    for t in xrange(len(inputs)):
        # one-hot-encoder
        # get zeros
        xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
        # place a one where the input index is
        xs[t][inputs[t]] = 1

        # obtain the current hidden state by using the regular equation for RNN
        # ht = tanh(whh*ht-1 + wxh*xt) where * is a dot operation
        # in other words 
        # multiply the weigths with the previous hidden state, 
        # add the weigths times the input of the current tick, 
        # add some bias
        # apply a non-linarity in this case tanh
        # this produces the current hidden state
        hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state

        # obtain the output stae by applying the dot product of the input weigths with the hidden state and adding a bias
        ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars

        # loss function which is the negative log cross-entropy
        ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
        loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)

    # inits for backward pass
    # backprop: compute gradients going backwards
    # dWxh: the gradient of the weights between the input and hidden layer
    # dWhh: the gradient of the weights in the hidden layer
    # dWhy: the gradient of the weights between the hidden and output layer
    dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
    # dbh: the bias gradient of the hidden layer
    # dby: the bias gradient of the output layer
    dbh, dby = np.zeros_like(bh), np.zeros_like(by)
    # dhnext: the running gradient while propagarting through time.  If you don't see it refer to the computational graph.
    dhnext = np.zeros_like(hs[0])

    # going backwards for each t is the tick for all inputs in the sequence. Again look at the computational graph.
    for t in reversed(xrange(len(inputs))):
        # upstream through the loss function
        dy = np.copy(ps[t])
        dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here

        # upstream through the weigths    
        dWhy += np.dot(dy, hs[t].T)
        dby += dy    

        # upstream through tanh (derivative of tanh)
        dh = np.dot(Why.T, dy) + dhnext # backprop into h
        dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
        dbh += dhraw

        # upstream through stack (see computational graph)
        dWxh += np.dot(dhraw, xs[t].T)
        dWhh += np.dot(dhraw, hs[t-1].T)

        # upstream thought the next input
        dhnext = np.dot(Whh.T, dhraw)

    # Mitigate exploding and vanishing gradients.
    # if the largest singular value > 1 in any of the gradients then you would slowly increase to infinity and explode
    # if the largest singular value < 1 in any of the gradients then you would slowly decrease to 0 and disappear
    for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
        np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients

    # return the following
    # [loss]: for logging
    # [dWxh, dWhh, dWhy, dbh, dby]: grardients for input,hidden,output weigts and biases
    # [hs]: the current hidden state which will be the previous state for the next set of sequence in the backprop thourgh time
    return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %% [markdown]
# ## Sample
# Get sample from the output distribution

# %%
def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is the current memory state, 
  seed_ix is seed letter for first time step ... basically the starting seed to generate the text
  n is the number of characters to generate
  """
  
  # intialization  
  # one-hot encode the seed
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1

  # running array list for the outputs
  ixes = []

  # go through each tick to generate the next character in all of the n generated characters  
  for t in xrange(n):
    # forward pass
    
    # calculate hidden state
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    
    # calculate output
    y = np.dot(Why, h) + by
    
    # calculate probabilities
    p = np.exp(y) / np.sum(np.exp(y))
    
    # select a random with some probability associated with values
    # np.random.choice(allPossibileOutcomes, probabilityOfTheOutcomes)
    # choose a number in the vocab based on the probabilty distribution found in previous step
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    
    # one-hot encode this in a vector
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    
    # append running vector outputs
    ixes.append(ix)
  return ixes

# %%
# def sample(h, seed_ix, n):
#   """ 
#   sample a sequence of integers from the model 
#   h is memory state, seed_ix is seed letter for first time step
#   """
#   x = np.zeros((vocab_size, 1))
#   x[seed_ix] = 1
#   ixes = []
#   for t in xrange(n):
#     h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
#     y = np.dot(Why, h) + by
#     p = np.exp(y) / np.sum(np.exp(y))
#     ix = np.random.choice(range(vocab_size), p=p.ravel())
#     x = np.zeros((vocab_size, 1))
#     x[ix] = 1
#     ixes.append(ix)
#   return ixes

# %% [markdown]
# # RNN

# %% [markdown]
# ## init

# %% [markdown]
# ### Pointers

# %%
# keep track of the data index as well as the iteration 
# n = interation counter
# p = data pointer
n, p = 0, 0

# %% [markdown]
# ### Weights

# %%
# initialize the weights all to zero
# mWxh = learnable weigths for input
# mWhh = learnable weigths for hidden states
# mWhy = learnable weigths for output
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)

# %% [markdown]
# ### Optimizer
#
# Here we are using Adagrad so we need to initialize the cache and the eps.
#
# ![AdaGradImplementation](https://i.imgur.com/p9IvCME.png)

# %%
# memory variables for Adagrad
mbh, mby = np.zeros_like(bh), np.zeros_like(by)

# %% [markdown]
# ### Loss

# %%
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0

# %% [markdown]
# ## RNN Start
#
# Note: this will run forever until you terminate.  Maybe later if I have some time I could add a logging system and maybe a termination loops. For now this is good just to see how well things work.

# %% [markdown]
# ![](https://i.imgur.com/7OpZrWz.png)
# ![image](https://i.imgur.com/EwjRQ0C.png)
# ![](https://i.imgur.com/jzIcL6x.png)

# %%
while True:   
  
  # Step #1 Truncated Backprop through time paradigm
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  # Because we are doing truncated backprop thorugh time (by 25 steps) we need to see if we get an overflow.  If so then we need
  # to initialize everything back to zero.  this means that the previous hidden state is now 0 and the data pointer is also back
  # to zero
  if p+seq_length+1 >= len(data) or n == 0: 
    # reset RNN memory
    hprev = np.zeros((hidden_size,1)) 
    # go from start of data
    p = 0 #

  # Step #2 - Obtain Inputs
  # Get the sequence of inputs in the database with length seq_length
  # input is a list of indicies in the char_to_ix
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]

  # Step #3 - Obtain Outputs
  # Get the sequence of outputs in the database with length seq_length
  # basically the next character of the input
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # Step #4 - Backprop and calculate loss
  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  
  # Step #5 - Parameter updates 
  # perform parameter update with Adagrad
  # This is an efficient way of looping through all the parameters that needs to be update
  # zip each group of parameter types using the zip function.  
  # So the zip function places zip([parametsr],[derivatives of the parameters],[memory of the paramters])
  # loop through them so in this case it will first take the Wxh i.e. the first terms in each of the zipped lists.
  # In other words 
  # param = Wxh 
  # dparam = dWxh 
  # mem = mWxh
  # then you apply the adagra update rule
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                            [dWxh, dWhh, dWhy, dbh, dby], 
                            [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  # Step #6 - Randoomly sample what the model is generating
  # sample from the model now and then by outputing what it generated and also show the loss
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print '----\n %s \n----' % (txt, )
    print 'iter %d, loss: %f' % (n, smooth_loss) 
    

  # Step #7 - increment the iteration and also the step sequence through the database.  
  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# ----
#  k
# s t
# Topuomoimfjl
# fkfoy
# HHn
#
# fgnim
# yhmfev
# ukfv
# nc
# fnffmffwnmAmmjwAlrfmIm
# bfy
# nkgmfpfmshmhfImfsn
# T
# jmknNrs
# mbm-yrlffiyreI
# f-mYysdct
# tNcdfm-mYmg
# mykyhmn
# mwA
#
# nfkmnrfnffyyky-ffnfA
# hmmjme-Yp
# Nf
# YYfnffe
# P
# ----
# iter 0, loss: 90.272953
# ----
#  au stesinsa a Wsunauns ssuosery yIu' r su srdsi
# k ial sw sayf  ol
# oI sewsu socr dst mm snfs
# debnst s nha po
# ba
# s as sonts
# iwsibnissrs  slmoonauns nao sv s  sinsens  ao s
# ap nsunsnnsoio-tsuysm st ao g
# ----
# iter 100, loss: 90.683533
# ----
#  I v
# lw -W
# ktowims uYoa  ae
# lohgha hetyleo owmbrmly ffvr ns elrre oiroWnoYrsohee ir
# o
# oe huAtnrg Ayolt
#
# esur fnor s toe ri  iwek
# e  o td wledd  os
# oc' sh
# lwlltilsoa enwoi io fthgn otllo
# aWwinw toid
# ----
# iter 200, loss: 89.498037
# ----
#  kh youoro rg rom'
# 'v
#
# v nP'YotjirTFusrkuu
# l  tafdWW yoigrFeid
# IohoWwnWe hywi
# au nFidtyW kef lgfinl' tWW nofe-p p
# -c ptg nybpeno o'mAitkuIh  hf  nTgirco ahfaooF
# iW nTao
# m toivAho uhoyodbI tiIuoIgnuy
# ----
# iter 300, loss: 88.536869
# ----
#  nuihl twhreiwgtinroth nhintl aeoIani
# ddgod
# ffenh  mtt yhe'n
# n yr u lit letg  nao awfoInT tyamhoooWsituloral'II weFtlyd'oyavorafweglo nglo
# Wl l ylio dAsw  oueas og dor'ho tf  g le'un'tot rv tto
# hlot'
# ----
# iter 400, loss: 87.121553
# ----
#  thllon Iovo hoat 'aco-ewte da Wanenin esg tse
# atitltheTmew yg us uerg n ngdati
#  ee yos ninal  wot
# me dye wet
# jls hea
# m bim Iou owith yhas e th somo
# Witabes mfomn
# Tlk mg
# mw no the tinily erdis
# ----
# iter 500, loss: 85.294432
# ----
#  ww t'g
# yhathn aIle yfd ns thing wro lHdlt -oW kou wlah fe
# Th oN
# Att gbne nee w
# Y doal
# rhoanings th e o
# letl
# it ttt thjn woe bouoo
# le's
# Ann
# fowts tere w wyFme lve Wib ghe
# vewin aAn yain yhue
# ----
# iter 600, loss: 83.217966
# ----
#  donl koutl radwlt owaaAtfe sath no iatisdr of I atl'wol Iousomenotkinon
# ydortheinky
# Wim
# war-tall iousot tebe Iitwakgem new Whoe ter  wheing tolk abou your thsomod f feIhel  le
# ameas
# I oW
# abuo
# tt
# ----
# iter 700, loss: 80.923469
# ----
#   eu wus roudeeimfal Hour lhiathin'y behe sh aals
# WinPll tl al sond l'jgdlid
# dl tes
# Wing tf te gourth h yl roreheeu ou mou Iou nF whr thof tlithat Iou
# wht t liyingl t avy rt tire s theingithirg Ig
# ----
# iter 800, loss: 78.555774
# ----
#
# Ang yomou
# I horar afouser fobe g wiiv ll'teeawnyatekt I'y foding I'ys afew or ave soreuh
# Nokt
#
# bIayeee shead jor ell fos I ikgl
# Wallese aheisnd eut tll bu Iy oWells avsing uathingisou the Iam giwe
# ----
# iter 900, loss: 76.085170
# ----
#  n uling s
# YI of th ing shmloy
# fotel gon Phit met loons tl orem aher that ynouo  yout rwoen glouresoo ing wingi glionyin' werlse yoat'e  Ior yououim ehim  khe te Wom
# Pdons yoray Ponend
# our douing n
# ----
# iter 1000, loss: 73.676032
# ----
#  aWld wo whin
# f
# Nalsill tlouth Io'meindowh
# And om I' rithasNd te fouhs ke
# An lok
# Whoyn
# Aselt whan ber
# whoel am om f rekeme yoon  ba l'ju I'dl gNore senel Ioev doelis
# Whep f's dout Iwiikg dowin
# ----
# iter 1100, loss: 71.246966
# ----
#  llor benine lious lyof mwe llon of gind wit'l ey doret
# Nouss dowimhle b
# v ame me yor e al u Iyirs llesing me
#
# Whing beted
# Whind de llonel I ham
# Whwere or tlewtinI yog lhahe now bete
# Yd aoteoe fo
# ----
# iter 1200, loss: 68.918600
# ----
#
#
# Amthe Iirc -onee awls king fou leoun
# Hhas
# cocetnd wall d elt
# Y- ahunt
# Heur thaoHen yg de do el
# And
# rave
#
# Af whorey ye d'm doutt whing o's sotes Is I Io knd tha ing w
# Fet theeiing
# An wh olen
# ----
# iter 1300, loss: 66.598201
# ----
#   elehlen soutsihed I'ings goneg wiwdasin jP
# You let nof ore ile ml nore ous g'd marysigel witithou
# Ang du whe outwon wes lout sool sereit bers
# I'Ye fe n  oue inT's wwitt lser thokt serlou fows this
# ----
# iter 1400, loss: 64.397474
# ----
#  g wndorsimtlPownow
# Ahene oor ngid am yY'm ave I't am es oo
# Have
# What joing shours tttsothoIsin amall be no all walit be
# hotns Ie of ne of thke g'se fos nooul wo-oing
# And foom sof gor de ou fom n-
# ----
# iter 1500, loss: 62.202071
# ----
#   whithyou ng ror thtraing dowing yor whid sewe Iw moring whouts doe n woo nw wales
# 'Y foeit
# und dole lme
#
# Ams sion aFt nowel yokn ind alls I'd mout
# I'y
# Weam wp
# W lkt Iu tho nd tlar wor fet nore t
# ----
# iter 1600, loss: 60.155716
# ----
#  g t
# bets tl'wn
# vethare am the then witt I'me nowr yout aWll oYe hing withoking m m de out ls kg elle
# Fore or I I'vn
# I'y I ne meen wIathas Iing that youen doou nhat mu eor
# At apl thhest ou myou se
# ----
# iter 1700, loss: 58.076253
# ----
#  lehe atlst ow
# Nole awow
# Yoin I'l titinnbe me ouray
# Whe now
# I'r bet you me thI tithes
#
# I av ou gom tht sod sithet no hid ae of
#
# I wall of nowes rithan soml hind ayle alinn woou me fuInd ou
# Ye in
# ----
# iter 1800, loss: 56.215718
# ----
#  sithe thone
# sorithaigd I'lle-ou gor ofofe ele d onode oetl yous
# An bwnd ehat's of me I worese alaly -oosom of n
# d ehe yitowsinithe you dowslam hoon whound fores giwhe forahsd amewi
# Whaal
# Have neAc
# ----
# iter 1900, loss: 54.317996
# ----
#   all ou
# Fw I'm wort whoaishoI thound fe ting fow t'l wighat
# g leleyl sore
# Whand dor thing we lind oun ind ow wooku
# Sow
# And alat whe same me
# I I rling yom fof foor me hoyt somad
# Whad irpl thaw i
# ----
# iter 2000, loss: 52.658236
# ----
#   Io-outhirsal loebe
#
# Yout iwnw I I ram
# I lityoutle bets I'be he nout
# bereneitham
# And Ie owtling down you
# And
#
# I fereket you nid sor thing dem lleting reoun ine hatheon
# Whand m all om dof dore o
# ----
# iter 2100, loss: 50.903343
# ----
#  e'vy
# Whathatmw Iithing ootToke lout all lwte
# Wtan youst of out ing mer thind oooney ooe he al aikseou aplve noese ifis'm tllind r
# I'l you tisgon nots wal owryous or goret sooes amae Is
# No iI a'w y
# ----
# iter 2200, loss: 49.342679
# ----
#  hat avething
# bete younay
# I've out ou lithabatyou ooones I out'g I's I goned loe doo nou wnal a
# Thave li
# pAnd wor soondu weling wing feretian I'm son thatyam afeselinPs wido higt you lhe bokn
# I've s
# ----
# iter 2300, loss: 47.754980
# ----
#   r te rere nome I tlvit t lit mou
#
# Whe yowig fe
# Wout
# I you mof ou
# Whayt aAyoun uhme sithad wg ous you biis bee some feeeing fooray foos
# Atll tor nof lit you sad to yous iI'l of t ing
# betl ou
# I
# ----
# iter 2400, loss: 46.286073
# ----
#  oTtny fownd jitll soo-ithahe  horykisy wave doin I I llokind nowelr foe gow youtyowes
# I all it youtyl wof wale lut kit leling wing
# Ando te inen t'll wirldoor ourlee you sod
# We m wof an
# Whayhu fou
# ----
# iter 2500, loss: 44.871543
# ----
#  lin
# And ow baysing I't am fe lt t ans fel the
# Hatyse avay
#
# Ween jut ing thr ae Ierityamy I'm doing  As you thou ging whate the
# Yings of fog soott igot labg simes thin
#
# W'lll you do elis
# I've ge
# ----
# iter 2600, loss: 43.537599
# ----
#  thon' you
# Ang I of things sou ge donoknwsan fo rathing weal welit
# I ratt
# I'tis allin yow thind horo
# What lo out wime out am'l ahat's withnd ow
# Sow ing med lithouns alHad Iel all I've bese hout in
# ----
# iter 2700, loss: 42.204169
# ----
#  ing wimhthortipng oues bg s gorlde doe
# Yoongabe l'ylw behkng rlourd or ahad so g
# Thoys butting wim
# IW ins foke or ehat am dove
# Tout
# I leee
#
# Weling ahat am
# Pelid thiring withone it lele
# Whanwind
# ----
# iter 2800, loss: 40.971150
# ----
#  ynd ave
# I all of ne wninow
# Wele aing for somee it loing feenay whatal you
# Whay I'm been
# falindw
# SWhomebewse
# We homes
# Toline rlou
#
# We gotl gor you yone heoe a
# wites thou
# What ealt
# Feretsyone
# ----
# iter 2900, loss: 39.760813
# ----
#  yays
# Anee cou fe in's  hitsin
# Wheing ne the no rous
# Ibene fone ellit t withaidhe elsen sores lhos tithing wiwhind ow lithnnws I'ves lof
# Hame bees now timnond her
# Anbe you
#
# Fou
#
# Whiin I let you
#
# ----
# iter 3000, loss: 38.605234
# ----
#  o riret lallhed i
# cvet thing well out yound  fore now
# I letone wont I'me berke fere no-ingy
# Wh nge yout
# An roe
# And
# Ih eling al oot none afer
#
# Well foren woitll me tla
# I'll reottlings be fe latk
# ----
# iter 3100, loss: 37.473979
# ----
#  ousis dore ithou
# Whamya e ell
# Whee going hof somese f tlifone opskis
# Whe we so sat the ou m thays now hing alle of me st's do onid that soapy
#
# We you doon yam satis o-one hort ydon I
# Ar el out in
# ----
# iter 3200, loss: 36.329504
# ----
#  el of the t lit's wmoe
# Whanway I foing wighoung me  ofe ine beout
# Yound you'w weeng wore lling oon
# Whe gor all-one eitlais gom
# feat all of ave
# I ave'd wimu bees
# What am wate l cou
#
# Wele out ine
# ----
# iter 3300, loss: 35.257679
# ----
#  ouen onewr ayou hokn
# What you gound oe beesing when dowing hortt dor me witlint fe tine  mon
# What am I'm tlit ahalis ourp-a yoo
# And withad nownd of the tome
#
# Wele that am I orl ikiking net amy I m
# ----
# iter 3400, loss: 34.183729
# ----
#  le I found ewll im Iet allout ofeing sore he el noe
# What amell ofe
#
# Wethe that thaty
# Andys ous o oor yound dot in wf forst mes foerone ows ofon of oeel awe fee am you I I out loaigg wetror noing f
# ----
# iter 3500, loss: 33.184276
# ----
#  down rome or thing ring nor thing rigs gonay
# Welll thit am jon Iow hom the butling
# Have alway
# Weling foehe down
#
# W ve lo ge eling mit litlings bet
#
# Wel loe thing ne rit thow
# rsap all no-own I'v
# ----
# iter 3600, loss: 32.151534
# ----
#  i
# I wot's buet lin out inow
# Fo lytithound ous harpd wtlayt woelt lmound I outling me oling t allooknd ous watet ou doo ewsling we hing le bend all the yound fout
#
# F me all tha get now li
# What thondy
# ----
# iter 3700, loss: 31.183165
# ----
#  etey
# Haves doer
# We I'meje lhir
# And all of
# 'm kind for out isamy dor
# You wewe
# An
# Whoy
# And alitewelin
#
# Wel yeem afaIe lookn ew linow
# As me kig
# I' loes'm do oain  mekt nowt woyl om thay
# Whehe
# ----
# iter 3800, loss: 30.259237
# ----
#  ou that sookin just lu me buran
# Is been imys been I'llle e'my
# Whael ams le
# ge le things bett mayse vesen
# f mwt
# me of my do-one onl ee litll now yo loking I leave llou
# So ten wfere ouswels ow th
# ----
# iter 3900, loss: 29.426971
# ----
#   nof
# You gome hoor nows
# I mat yout yout ing tha tithut
# Yout you
# And alidownd ou nookny of the things bes
# And all ow
#
# Wethat you
#
# Welling f ows gves
# fook
# Wham sore-of
# And dot ing el ke ow
# I
# ----
# iter 4000, loss: 28.626923
# ----
#  wit lithat I lokinb dling wryool ime if I've l's does
# What oorn
# widhing
# Whany ofellingt yoind of the gom grtrin whind of horenk
# An you
# An
# What am dof taleting wekimys doing withing wisho hithall
# ----
# iter 4100, loss: 27.861551
# ----
#  all fout
#
# We utst in
# Wham
# welling foe
# Have thar I tas aying I lell
# What you
#
# Welm bes king door
# As
# No ouoc
# And beany gotl ooonowne been you
#
# What am I do-nou ne of t's thout yyoutsyous or
# Y
# ----
# iter 4200, loss: 27.215196
# ----
#
# Whay I dewy
# Wham sors oreno
#
# We g noutsing bee on
# I'l all ows hoes
# Wele found witha lore  foehe outt doonithonow litll bet atst g tlling fale I I aling outl  of
# And
# Welis doing githout you
# You
# ----
# iter 4300, loss: 26.419238
# ----
#   s mas
# As
# Wham aI jam
# Wele ce sou
# Have amy doone n'm sor noa ig aking me of my doows all out you
# Whas dar
# What am jut's alle wiretend of ther
# And  I'm
# ve come  fall things I've betny go ew ino
# ----
# iter 4400, loss: 25.628097
# ----
#    hate
# Hal a loweys
# What am I'mys weesy I'm of thund of out heat soall of me been
# Sd fot ayly ghan the theoking no ewnes
# Yfan I doing wight t out sooney
#
# Well bittings been I'd wone soall  fon th
# ----
# iter 4500, loss: 24.904010
# ----
#  ng  Wamu ma gorets me walking forse hone bet's doon
# Yo ome giuns doout
# No so
# And oet ittt iww Ieay fon I'm borlin
# I've been lwas mat aI jetling alN ows
# What no ig's ous I'm juspys I'm doing rlas
#
# ----
# iter 4600, loss: 24.226864
# ----
#  ling we heings I'd feels fooring fee net iut akiwy ohe
# It amw you gom
# ge hone d's le may
# Whprat've lidou
# And all of ne kithe sithonou nod or ber
# Wele lignd fe in wr oo lo iny
# Whet
#
# We g tithe t
# ----
# iter 4700, loss: 23.449733
# ----
#  y I I've berkis the's  goneyse honey
# Whayww whele sames
# No be se hayt am wlwove I'v beet nown loon
# Whas same beat of thing
# Havy dowd itha awligs doing of one els mut you sot ahing ow thay
# And als
# ----
# iter 4800, loss: 22.787946
# ----
#  than whee thou gmtest all titlwen be thing f me's all of do sor
# Have all oor nownd fore hays I'm wYtsitling  I've
# No out
# And for thoor
# And asd of me fe elnowkt I feing hor
# What apt att tlle ig op
# ----
# iter 4900, loss: 22.146891
# ----
#  out you sooking womething ne rat's aram wowsy uhde else g'the onou avwowssithatways he's some whorething dookigidg whr tim I
# Weave loujnind fee bet thout atlls I I's len I've no-on
# I'm I'm lelet am
# ----
# iter 5000, loss: 21.544093
# ----
#  thipt oun yousound alla kise ell ing without you
#
# Tell your I've whent am I deve dou in's dooking feor
# And all eve isof s ssout yow
# And all ops ghe geer
# Whay
# I oocey
#
# ve l looking bees I of
# And
# ----
# iter 5100, loss: 21.026169
# ----
#  w
#
# We glwyt heo one gome o
# m
# We ehes
# What am I doing wite und th ows
# What adoing wikithae I irlays
# What soos
# Andy
# When
#
# Well that some how grings of the thisdo-o-ewsling
# I yI's ret's do anout
# ----
# iter 5200, loss: 20.451648
# ----
#  el youring whe bes yourint  or
# Have dorkng me halw
# What I bet's do itha wabe I' foong feokny not pyt you
# And  outt ar ayonebe Iewaking woop newd ofone elsing
# What sot's thays been you sewing for o
# ----
# iter 5300, loss: 20.021276
# ----
#  ele a
# Weym beet
# foat amy keallee kn ownd of mind romet some oorin
# Weal hofe honownd realewsing wing no ee gow
# What avewne withour
# I'l all ithimt you thon I's moen you gome bere ber
# What ave looke
# ----
# iter 5400, loss: 19.556850
# ----
#  hat s mat am I doonof the someshdoing withing new
# You may
# What all onet
# I let you in
#
# Welin
# mel
# Yeave be now wown woys allokn beer
# And eem af mou no-one gow beenny own of the some that it
# And
# ----
# iter 5500, loss: 19.004847
# ----
#
# ve be sous
# I woout you gom
# ring rlpis
#
# Well of my womn wrar thout loing withat soavy
# f-oumn herse urlwon
# Ande thee
# Yom that I I alling widor
# And wirl in
# foo lor
# And ofe hee ing thout you
# An
# ----
# iter 5600, loss: 18.527734
# ----
#   sou
# Haven toing downy thee now one beer
# And arat lound ewt's do isome hor things I'tll sithind oithing rimy I'mell de me things I've thetlate where oridime been soms you
# And aved ele ereay I what'
# ----
# iter 5700, loss: 18.026544
# ----
#  you sookn you
# And I mwe hon yown
# mell oAs eoking for tome now honey
# Whave wwar I'm ofonen been
# No buts onow the you sotey
#
# We Ang without I ooone lithout you
#
# Wvee gow
# You dokn soteou mybe thin
# ----
# iter 5800, loss: 17.511849
# ----
#  ling the wobe heoking me feel nou thin shers for the things m been
# And elound looing m I'd
# I lee
# hetrew
# I le lit've baen woeh hop doown worl yow thbessakway
# Whakind now ine fout now
# Soll ing I'd
# ----
# iter 5900, loss: 16.964794
# ----
#   youn
# What you walp soo-ouns onow
# I outt
# Yom dond some ing oAn yre thor time I'm lone ond alet ing do romeI mady
# Foweys rithing wale lorut
# Wititht ing tha wronew
# What iI ound ind or lisipl
# I ou
# ----
# iter 6000, loss: 16.505338
# ----
#  ewn I I's jund no ri
# And all of mel wall ou t amy
# IW lle out ing ruthins ritithan all of the tale se elle ofow sime thout ew you do ogot am I out in te mit thout hor som thing within s I'd fet't al y
# ----
# iter 6100, loss: 16.024586
# ----
#
# Pray
# ver
# And fooling aram someon wPrwit sitl
# Wu gon
# IT ittsayl bnes her e't oo oue the things thee knoke greng
# It plous
# What am I'd alet id of len you down
# What am I I sotlind foo hing for no
# ----
# iter 6200, loss: 15.766248
# ----
#  ofing wimy
# Whaking that igt oo
#
# Fun you
# Whataid oust lire you nowr of ing feel you the simes
# I'lling fee alout ine alitean
# Ihalle thinga whete undoone oro gnow
# Soll of the thit
# I'd loysu
# Whad
# ----
# iter 6300, loss: 15.494097
# ----
#  om door
# And in I jus
# And yWe ou's feel you
# And all ell ing IIt'se there out thout out
# Whamy dewd
# And foel you thin-one canel you
#
# Telone in I doing forld oks got ser be somy
# I leteat ife kf the
# ----
# iter 6400, loss: 15.174306
# ----
#  and feeet now
# I llit's for
# rouss
# I reone elinn
# Yere you wome hor
#
# Fun yaing what's do out you
#
# Well I doeling rorld of ne do no ritran
# I own
# IW lone newel youngs I the wngt in that am gasewnd
# ----
# iter 6500, loss: 14.755743
# ----
#  Wellone ghm yat some one hing rldounn ferl yow famy urthat am I ofing
# I've ne for thousing you
#
# Funn
# Iele feren
# I' hone erit I I ofe ee eaitel am I all of
# Forldooring door doing without you
# Tmay
# ----
# iter 6600, loss: 14.400944
# ----
#  lu ghthnowhrarhan y mat in
# Well ame oo litts mets
# I's doing wings lw soue nows
# I'm just bean you sido ofen you some sorse ousing feeher
# I wond fr the thin
# Thor m
# An
#
# Weat am doing rlae an I doip
# ----
# iter 6700, loss: 13.988311
# ----
#  s fame at'my
#
# I lin wale bee
# And all  oole  cout you
# Athing withs oun nou
# Hamy
# What ar wall ofon r be that you do littne ally
# What am Ialw
# I'lle all eel tooking for something wnyo eweys rimyou
# ----
# iter 6800, loss: 13.582783
# ----
#  ne bees like tho's
# I've now
# What am I doing wise the some hat oundo honew
# What am I wall forse alising wott herit's worlwno-on you bat ng theowit lit's do nor m soole yout' whore yound some foe
# An
# ----
# iter 6900, loss: 13.235289
# ----
#  ing wisow hor
#
# Fut no le kn I I's aling I'm beethore noe
# Haven loou ghout you
# Whayy beel you
# And I f trimy my
# Wh ou's reokn louts
# Whind oo's foen yout you
#
# Toer
# And foel you in foing
# I you
#
#
# ----
# iter 7000, loss: 12.905834
# ----
#  outthist ou mimd whw mays orone foryt
# So lit's withour
# I'll eling I rling wrrlour rithan  ohe githout is'm soalwiny doun
# What someone whing new
# Wham id ow
# I feeng mid ooround all of titho-ing for
# ----
# iter 7100, loss: 12.560759
# ----
#  ls hoa
#
# F beran
# I-owing down
# Theet ing do llonown I ale pI mat's or ind ofr lone you come I'm
# I oele king withit thing dooof no of the nohew I doing me eron
# AnT wornd oer gown
# mele hoo
# What all
# ----
# iter 7200, loss: 12.318300
# ----
#  when I'm foel you ghel you comid telet yow
# So lit's
# fevehing righouring whet ayling me ime thing ritha Iad just II lloking for
# Have always been here outsidhat aben ere gound all you wo louts ofad o
# ----
# iter 7300, loss: 12.180028
# ----
#
#
# Funn yor the pe I'oforingor doone was doing without you
#
# Well I wall  oore all it'm
# Ihayin the things I'vewdy merkn sale oksing that some hor doing new
# What am I'd ort ikg withing dewd
# And foe
#
# ----
# iter 7400, loss: 11.919799
# ----
#  d out igewn you
# Sod onow belys fotry
# For thing without you
# You make ronet lfeke hor no erramy fow
# You wale seal
# Yison
#
# pve ysinown
# I all aI lore dois deine ainglw thayt someouy
#
# ver ne of the t
# ----
# iter 7500, loss: 11.563426
# ----
#  I'd feel you ind here
# Have knows fathe thitgnme hels
# And
# I les the t you wime wheno somethere had ing tethound dooking fe our own whe fatbut yom
# Psreound wit amp ave be things I rpel you s doing w
# ----
# iter 7600, loss: 11.361402
# ----
#  ing newn you
#
# We gor githings I'd ale ell outting I rlou ghat you cooYing aroung newny doown yoone slmeone I'me fors
# I fing new
# What amal Ieell our
# When you
#
# We I'd ofoke hone erey
#
# I lise ine h
# ----
# iter 7700, loss: 11.117804
# ----
#  ing whdou
# fat ino-oney
# What am I doing witithnd goa lhing without yo-onowher our of younnewnowny feeliny fithut urys dows
# And mat all ke Ithing r thitlat you
#
# Tole
# And all of the thipc hows
# What
# ----
# iter 7800, loss: 10.903765
# ----
#  ousterl am myou do mis
# I feel yound now hone
# Yhat allat some wow sithout you
# psaykn I'll tenne  ou
# And wide rine whals meone gome feeno her
# And all if's wrlittle hor things I've been wdois
# What
# ----
# iter 7900, loss: 10.624736
# ----
#  oel of s
# I'm feels gf thes
# And all ooone whings I'd feeling rithing
# Prer
# And ayelind it loon you things I'm alirl ing
# When titlin
# As you
#
# Funny how liin
# Ie forl kime knoes four hor things thee
# ----
# iter 8000, loss: 10.333819
# ----
#  tthinn bees
# And fet's doing without you
# I me
# Whou wing for
# Have ogome ke mat kele loaling new
# What a'll bee
#
# Wele am I iremu come how
# And all the time I loout you
# Have gimn I've for
# Have alw
# ----
# iter 8100, loss: 10.018784
# ----
#  d ig ows I I's lloking aron lhor
# And all of t's trime
# Ile I's been afor thout you
# I wong now
# What af let sel ound oo'm foel yout ikg
# Att all af fat tele gownd rooes
# Whings I've been lor
# Ang doo
# ----
# iter 8200, loss: 9.695276
# ----
#   without you ghah now way
# It's trye  out ing
# Whee lighing wner gou
# You make no one else gows
# What ahe ehees
# Halbays wooing foer  fet you wime no ofything new
# Nel y
# rhat ing wit lithat am I doin
# ----
# iter 8300, loss: 9.380031
# ----
#
#
# When I've bey e igowe heething down
# Yhat sooeh
# No buts or foo now you
# You mowe honowh the thing dew
# Wean out hone I' here ya
# I lliny door
# And foorsou sitime I'm I all of thidou something fes
# ----
# iter 8400, loss: 9.100293
# ----
#  ofe ing thays yout you mal
# IW louhing without you
# And of things that am I doing witht outsipys of my
# Whee you
# And eldoe foonkny dois deing wore nd out here somet that am I doing without you
# And a
# ----
# iter 8500, loss: 8.919797
# ----
#  ng werloys
# I llset aheke me out ide yow wall wooling fort yous
# Whound or
#
# We gott no ple erout hops
# Whings I'sl mal you gows rows heorene iI monelw yoo gr pen you ceme loings I've beat am doe
# And
# ----
# iter 8600, loss: 8.997679
# ----
#   you
# Whit's if thing righrethat thays then thidg rithattit iseaking yom behind world be sor
# Have amalw been ways mals thirsromet ayin  fomed  orsthing for doing Yithore now
# What am thor hoont sitho
# ----
# iter 8700, loss: 9.085709
# ----
#   rlay
# Whathe timu I't looking me lling weel  oveng fooen you something deoe
# And all of doing withay you things I'sl thetein sebe sayse been soon you behind foing wis ofee king for dow watt
# Ang for
# ----
# iter 8800, loss: 8.889199
# ----
#  Yt tling widown
# What ir the goout t mout you
# And am doerer
# Andt ll e sookn wapld als the simeteliny fow
# Yound no oust her gour
# Whan just leall you
# You make welle
#
# Well ryan you
# You do for mat
# ----
# iter 8900, loss: 8.641839
# ----
#  hing wher ting Ihe things whan I've been anl reren that sored ithat ads all of the time ne else knows
# I let you igo twplinow
# As you than I ooort imy I beney I mal you
# And ald ou core loings thing a
# ----
# iter 9000, loss: 8.375700
# ----
#  sighs rere hatligh tha ime I foings I'se merse ees you things I'd well  fishcttstinow
# Fhe al that's what I foe ngt sows
# I let tho't yoo gor
# I've gows
# I let this slip aheing wing ehong cidoret
#
# We
# ----
# iter 9100, loss: 8.111610
# ----
#  ripHave ehat aw you bakn serel of
# And elt'y ior mhe ha'my
# Frent door
# And all ofe olsessar
# I lling al you me been like weor
# And all ofonew yowny I meal out's feele beeking onow hor be now baby som
# ----
# iter 9200, loss: 7.879620
# ----
#
#
# We mime all out here be sot now wayy ooe king dowd hoor
# And all of sher honeys down woen
# Yo let you in
# wh rin' wall sime ayseay t yoo ows
# I've couin widou
#
# We githout you soor m re ing tlse el
# ----
# iter 9300, loss: 7.696934
# ----
#  ne foeher
# Ang forhay
# I lling fer goes
# And fat ing
# What yukings thetsor
# And all om I wall t'm be alials I'd all als als doing my I doing wing m I I'h aI I's feelityows
# What aI I doe
# An yo-'d wit
# ----
# iter 9400, loss: 8.459952
# ----
#   I'l elsoe
# You make me feen like loing worldo forss ofe lime beeing
# I's feel you
#
# Weling wigheings been
# meld ooone  aI
# I let no-ong n I looking for ba wiwy m I lotling meld foew
# What am I doing
# ----
# iter 9500, loss: 8.686465
# ----
#  ees me feel no-one wor things that I'shan looking Ihr sor o
# Thone else gor doing withouting wews
# What lown
# I'wha bettt wighit me eling now
# And whel that's what thattit leyat t idTe honown jr the thi
# ----
# iter 9600, loss: 8.693272
# ----
#   I'm fave lifer
# And I ofe eline for
# ut plings me seve somethent somes doing wha things I've le king fof my I f mo e tiI I'm let you things I've been be you in wind noer oe s mathe things f retrac I
# ----
# iter 9700, loss: 8.613020
# ----
#  oings I've falling for
# Have alla fore thattit's alwake hon whe things I'd feeling ar mown
# I've
# And eve al you
#
# We gownts
# What amateall of that someonown
# I wethap sored eone bey thatlayse
# Whing
# ----
# iter 9800, loss: 8.441702
# ----
#  outhing doing wore ywows maal I ifeou things that o-one here itha war
# It's heran I'd woes
# Well it's doun you one horldy w ovean awle the things I've been lot's wist ing f s mat am
# It plitying for d
# ----
# iter 9900, loss: 8.194889
# ----
#   dooon loor
# And all of the things I've beel hoo no one else you in wher doing without yoh tine Ior
# Pr nou
#
# Wele gotlys
# me gooe is met you
#
# Whay
#
# Il
# What am I doing without you
# You make me feen
# ----
# iter 10000, loss: 7.919948
# ----
#  outwn
# What am I fat toout you
#
# Well im wave liay tha the
# Prayiny whout you
# And all of bend of my fimy
# I mou
# Ane berifewn the things I've doing we It lla on I' ll t looking fore hone someone yome
# ----
# iter 10100, loss: 7.625698
# ----
#  lu
#
# We got a little seokn ewne hout'- al all of theouns rinown
# What am I f the things that alway
# Yere ideing rone else gwes
# And all oown soo out you
# Haves doingt bet yo-one uhdehappuriY's lime m
# ----
# iter 10200, loss: 7.352320
# ----
#  kn I'r
# I lout you
#
# Wellyse heoand of my do kn the out ing ahersht nogs of meran
# I ll tes thone no-one ehte
# And if let you de ofer
# I all own alll tithat ave somee kithout yaves
# I'll tell ing with
# ----
# iter 10300, loss: 7.081356
# ----
#   wing Iroese onow
# And all of thurnn
# rime I teave of wnor
# And all telowey
# So lit's the sowe hof thing fere ke sout ime line nom of sothan wamy fome Noes
# I lise tho's just like you s of the thingin
# ----
# iter 10400, loss: 6.852855
# ----
#  oor
# And I swear terering newn eweone doing for
# Youid
# Yele you gowng wishound ithat all  fithatlings the ouring without yom things I've been looking for
# Have always beend now
# And eloy
# For the th
# ----
# iter 10500, loss: 6.639224
# ----
#
# And withanbars walltsaAn
#
# We I've loamy
# Wele been wokel wowld I tlou now wnowse woingw
# What am I doing without you
# You make reout you foings I'm ale tithat tlig's looking wor gn for time I me Iehe
# ----
# iter 10600, loss: 6.449836
# ----
#   of the thout hooe you
# And all of my
# It peay wha beheyour go-one gotring
# I find some forr
#
# We got a little woa ine mabe one else knowny
# rall you
# Preee
# No buts o-one else knows he's doing within
# ----
# iter 10700, loss: 6.299744
# ----
#  uhouryour
# When I've been you
# I lere you cor
# And dorkn
# I've no oun you in
# I de
# me for trip
# wn gome fou nowe I'm looking for
#
# Funy
# Whee you come eooy dol t'l tuyou
#
# We gownd of ouc rlseoking fi
# ----
# iter 10800, loss: 6.258573
# ----
#  all you kn waI I'm justheren
# And wide eliny aling do eoknd ono of the wang ne ofeay
# I you you
#
# Funny hodt ound af routs wigit pind all of loing mithis
# As
# I let you ng d's of ting fome
# What in
# I
# ----
# iter 10900, loss: 6.142556
# ----
#  I'm alll the things tele toke I'me fo-one gome looking without ngownw loing newnd been you
# Ane eway
# We I ing withound is ou som gyt you
#
# Wu ghan
# And find now hone elsy unde
# Ie ling I ll I've I mo
# ----
# iter 11000, loss: 5.982487
# ----
#
# Haven tall of thidoows I'm of my door
# And all of the out ide now be niwn jusy
# Wh outsine hors
# What adle our ewde ar teseal I doing without you
#
# Wh of ofrat be someon
# I'dw tithousighe serer now
# ----
# iter 11100, loss: 5.800700
# ----
#
# What am I doing without you
#
# Tot seshou
#
# And ale ko ows
# I lein
# Ihat that all of mnows
# I lea you
#
# Funny hott you cowbne ne rling wif sigh hone I'm fueling Iows hateing for on w call alway
# Iof
# ----
# iter 11200, loss: 5.622533
# ----
#  s mat all of the things I've foebahs tht
# Powhous hee onn betel you grda limighs I'my
#
# We ghe yourin
# As if do lit's amll I'm tou
# And eld of that ng doing fithout you
# And all of meoes
# An be soms
#
# ----
# iter 11300, loss: 5.464799
# ----
#  one who saves me ing downd fors hoo hon
# I won that amy
# As loing without you
# And all of the things I'm heel you thing hewn
# Yore ine be you
# Youe lithings that no one here'
# Whang gial I'm I'slle
# I
# ----
# iter 11400, loss: 5.295969
# ----
#  d all of the thing door
# And ayle lown
# Whing arounde orlit sime I'm I all of the tay
# It I found ahetels amay
# Whe te uhe things I's feone fann
# I le gome allte thbes
# So lee'
# I leat ou
#
# Welh thin
# ----
# iter 11500, loss: 5.144454
# ----
#  beeking do ere mave been lois sher onowe  oves
# I let you in what's
# Ihane ouring withings I've liol yous
# What am I doing rithout you
# You make me feel happy
# When I leave hones me cane ayou
#
# Too of
# ----
# iter 11600, loss: 5.031402
# ----
#  it the thet ne ohings I've bee gooes
# What am I doing without you
# And all outthout in you wimn no ofet like some
# I'm just  fint nownd been lout you f romes the time got now
# Prayey
# Whaknowing wiof
# ----
# iter 11700, loss: 4.907524
# ----
#
# And f t's doing without you
#
# Toing wors
# And all of thee hunig I'm leoes
# I le king f seon the the
# Have heething we hoa
#
# I all of the the kn I'm am I doing do-one hoore you
# And all here hnown
# Wh
# ----
# iter 11800, loss: 4.813515
# ----
#  rhound of our or shays yo ous goms marwd all of the town I te ounny f the go-ings I've been low
# Prayin' whet you ing right for bit you woon I where sotse inownon berse une berutside of my doo iny got
# ----
# iter 11900, loss: 5.042632
# ----
#  e been loan
# I'll theteing m doole hor dooking now lit you
#
# Funny how loy
# And all of m I'h me hoone soret cone moret been ha saves alw
# What am I mave e'llit soutsing rlat you wore sooking hese camy
# ----
# iter 12000, loss: 5.324588
# ----
#  m I lheng doing without you something f seon
# Ihaling whor
# And Ie let's Ie been sound
# I lle ing warewn loo's always you
# Nhe thikew hatey
# What'n ay fou
# And beratthe things that all of the things s
# ----
# iter 12100, loss: 5.343536
# ----
#  rat no ofet like you come been
# I'me I doing fer alind am the things that no-one else knows
# I lele some
# And girl thound it's feeling mights I'r all of the time I'm all am I's thee
#
# We got you doll
# ----
# iter 12200, loss: 5.246371
# ----
#  fithound no-own
# I'll tell you things I've been loor
# Ano of the p hoout
# Will iI the time wove
# Whee you wonY n's leall
# me been of the things theone
# And all of the thing new
# What am I doing withon
# ----
# iter 12300, loss: 5.174018
# ----
#
# And all of the things I's feeling rithout you
#
# Well alw doond somet hor gor
# And all of the tithout you
# You make me feel hayst sjre gow
#
# Well kido or the thing newe all t'm ally got souts doing w
# ----
# iter 12400, loss: 5.026156
# ----
#
# I lerkn
# I sealn wimese fe behind
# It plays ow
#
# Funny hew life can be so sithay
# I's lit'l
# And alwy
# I'me I own
# I'll feene alike of ne fore all of the things that no one erout in I doing without y
# ----
# iter 12500, loss: 4.892505
# ----
#  ling without you
#
# Well als mae looking foing
# I mee ther ows ofou
# And all of the time I'm of'm feeling around it's feeling right am I lhendy
# What am I doing no ew ofe hitlipy in wnow you been ofone
# ----
# iter 12600, loss: 4.731264
# ----
#   hoe
# I woknown I'm feelidoe
# And all of m
# I'm I doing without you An you for
# Nou
# Praying for
# Have alwa I'm just been here aAnd rithout you
# And all of the things that no one else knows
# I lehe be
# ----
# iter 12700, loss: 4.581617
# ----
#  eteing no ouny I lways romeone hor onow
# What you do
#
# We
# Whay
# And alill ofo
# Whas all aAs yoo no beey
# What am I doing without you
#
# Well it's bend someones loun
# fou fom thoust got young heout you
# ----
# iter 12800, loss: 4.432528
# ----
#  ne werlo-one gownd fotha our oway Is olly the ou sown
# The's just litely fome hifat ighen
# whing for something nee ghes
# And foe gown you
#
# Funny for something fithout you
#
# Whan lithing d the the thi
# ----
# iter 12900, loss: 4.298911
# ----
#  oas dois
# What ou
# You make me ouew doing without you
# As you
# And I doing without you
#
# Took for grantes doing without
#
# We gotsa tithoutsing dorndo of on wher
# And allle who save
# Ylle a littse hite
# ----
# iter 13000, loss: 4.202489
# ----
#  ou you somse ino foing now kn erse kofend foopsyse o
# sethe fat am I doing without you
#
# Took for githo saves meone who
# Whis
# As all it's fealy nowr Sooll tife come areley
# What am I doing withoms
# I
# ----
# iter 13100, loss: 4.121741
# ----
#  one come ewse gomnd wrete the thout you
# And all  Ialling ofer
# An you things that no one ne se've no one rige baes fo-own you god sof thing merehee knows
# I've been ben
# I'll tell yound of one sing
#
# ----
# iter 13200, loss: 4.050027
# ----
#  Whayou my myad  mat am I doing without you
# An I'mw
# Well you thints
# Whin sowhn
# I bee you you
#
# Fund als gwt you do
#
# We
#
# Tell no one else no-one here king right now
# So let's do it right now babp
# ----
# iter 13300, loss: 3.995940
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-1a776df9c838> in <module>()
#      42                             [mWxh, mWhh, mWhy, mbh, mby]):
#      43     mem += dparam * dparam
# ---> 44     param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update
#      45
#      46   # Step #6 - Randoomly sample what the model is generating
#
# KeyboardInterrupt:
