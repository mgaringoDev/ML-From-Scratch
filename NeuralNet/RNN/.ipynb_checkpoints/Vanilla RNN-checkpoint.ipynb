# %% [markdown]
# # Introduction
#
# This is my vanilla RNN implementation.  I got helped from Dr.Karpathy of the Stanford 231n profs.  The github implementation can be found [here](https://gist.github.com/karpathy/d4dee566867f8291f086).  And the original blog post based on this can be found [here](http://karpathy.github.io/2015/05/21/rnn-effectiveness/)

# %% [markdown]
# # Imports

# %%
import numpy as np

# %% [markdown]
# # I/O

# %% [markdown]
# - get the data from a text file
# - get the list of characters
# - get the length of the db and the vocabulary
# - associate each character with an index and vice versa

# %%
# Get the database from a list of characters that is found in the input.txt
# should be simple plain text file
data = open('input.txt', 'r').read()

# %%
# get the list of characters by first identifying the set() of characters and place them in a list()
# NOTE: set() function here creates an unorders collection with no duplicate elements
chars = list(set(data))

# %%
chars
# Out:
# ['\n',
#  ' ',
#  "'",
#  '-',
#  'A',
#  'F',
#  'I',
#  'H',
#  'N',
#  'P',
#  'S',
#  'T',
#  'W',
#  'Y',
#  'a',
#  'c',
#  'b',
#  'e',
#  'd',
#  'g',
#  'f',
#  'i',
#  'h',
#  'k',
#  'j',
#  'm',
#  'l',
#  'o',
#  'n',
#  'p',
#  's',
#  'r',
#  'u',
#  't',
#  'w',
#  'v',
#  'y']

# %%
# obtain the size of the data and the size of the vocabulary we have
data_size, vocab_size = len(data), len(chars)

# %%
print 'data has %d characters, %d unique.' % (data_size, vocab_size)
# Out:
# data has 1681 characters, 37 unique.

# %% [markdown]
# This is a text file so we know that there maybe 26 characters from the alphabet * 2 because of the capitals plus punctuations.  This seems reasonable so let us continue.

# %%
# enumerate the characters and give indices to them
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# %%
char_to_ix
# Out:
# {'\n': 0,
#  ' ': 1,
#  "'": 2,
#  '-': 3,
#  'A': 4,
#  'F': 5,
#  'H': 7,
#  'I': 6,
#  'N': 8,
#  'P': 9,
#  'S': 10,
#  'T': 11,
#  'W': 12,
#  'Y': 13,
#  'a': 14,
#  'b': 16,
#  'c': 15,
#  'd': 18,
#  'e': 17,
#  'f': 20,
#  'g': 19,
#  'h': 22,
#  'i': 21,
#  'j': 24,
#  'k': 23,
#  'l': 26,
#  'm': 25,
#  'n': 28,
#  'o': 27,
#  'p': 29,
#  'r': 31,
#  's': 30,
#  't': 33,
#  'u': 32,
#  'v': 35,
#  'w': 34,
#  'y': 36}

# %%
ix_to_char
# Out:
# {0: '\n',
#  1: ' ',
#  2: "'",
#  3: '-',
#  4: 'A',
#  5: 'F',
#  6: 'I',
#  7: 'H',
#  8: 'N',
#  9: 'P',
#  10: 'S',
#  11: 'T',
#  12: 'W',
#  13: 'Y',
#  14: 'a',
#  15: 'c',
#  16: 'b',
#  17: 'e',
#  18: 'd',
#  19: 'g',
#  20: 'f',
#  21: 'i',
#  22: 'h',
#  23: 'k',
#  24: 'j',
#  25: 'm',
#  26: 'l',
#  27: 'o',
#  28: 'n',
#  29: 'p',
#  30: 's',
#  31: 'r',
#  32: 'u',
#  33: 't',
#  34: 'w',
#  35: 'v',
#  36: 'y'}

# %% [markdown]
# # Parameters

# %% [markdown]
# ## HyperParameters

# %%
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# %% [markdown]
# ## Model Parameters

# %%
# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

# %% [markdown]
# # Functions

# %% [markdown]
# ## Loss

# %%
def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in xrange(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
    
  for t in reversed(xrange(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
    
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
    
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %% [markdown]
# ## Sample
# Get sample from the output distribution

# %%
def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in xrange(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %% [markdown]
# # RNN

# %% [markdown]
# ## init

# %% [markdown]
# ### Pointers

# %%
# keep track of the data index as well as the iteration 
# n = interation counter
# p = data pointer
n, p = 0, 0

# %% [markdown]
# ### Weights

# %%
# initialize the weights all to zero
# mWxh = learnable weigths for input
# mWhh = learnable weigths for hidden states
# mWhy = learnable weigths for output
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)

# %% [markdown]
# ### Optimizer
#
# Here we are using Adagrad so we need to initialize the cache and the eps.
#
# ![AdaGradImplementation](https://i.imgur.com/p9IvCME.png)

# %%
# memory variables for Adagrad
mbh, mby = np.zeros_like(bh), np.zeros_like(by)

# %% [markdown]
# ### Loss

# %%
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0

# %% [markdown]
# ## RNN Start
#
# Note: this will run forever until you terminate.  Maybe later if I have some time I could add a logging system and maybe a termination loops. For now this is good just to see how well things work.

# %% [markdown]
# ![](https://i.imgur.com/7OpZrWz.png)

# %%
while True:   
    
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  # Because we are doing truncated backprop thorugh time (by 25 steps) we need to see if we get an overflow.  If so then we need
  # to initialize everything back to zero.  this means that the previous hidden state is now 0 and the data pointer is also back
  # to zero
  if p+seq_length+1 >= len(data) or n == 0: 
    # reset RNN memory
    hprev = np.zeros((hidden_size,1)) 
    # go from start of data
    p = 0 #

  # Get the sequence of inputs in the database with length seq_length
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  # Get the sequence of outputs in the database with length seq_length
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print '----\n %s \n----' % (txt, )

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print 'iter %d, loss: %f' % (n, smooth_loss) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# ----
#  Niyepgl'bounNpAgrujYb--suucgsPsfHcrjegh-PAtmjPvtrfdIWvNmdmNTN'jjbA gecTY-erymoeNjaNhN'HrdWh'iiPd-dIPIskHYSFcWAtlubkAP
# Pc
# WobvgPdTntWparfYItvyarAtPbArsdvvin
# - AluTHmgiNduAPvF INHsPcg
# Ihy
# NHwAo'pbwjPbpj
# ----
# iter 0, loss: 90.272944
# ----
#  hhtIreI nomorulil
# Fun  Ayafi  ytkesiy sne
# oajrsuyls obW
# nnw oiu
# AYooyol  d iy'
#
# lpr livtno i iydcon soyiw v Iisoyiniy ynk mkril yih kn ey r eetoyn u owiy gomeanwdvt ndidoy sie w'bhmlhitohinu ryoto   i
# ----
# iter 100, loss: 91.501903
# ----
#
# kt hWsei n som l deh wkN m Aes ytd nhi n Aoe iFm ino hof yek
# v n sn-
# WWow wtg how i g eou f d
# I'iet cetel Iak y d
# ak- sakfiaF I Sel soHk
# hI   gsgoI re' wntasoi w g f ino wude-hyoilnYt les dog w leI
# ----
# iter 200, loss: 89.998431
# ----
#   teeau oky rwing puongsu  non blinomer a ons huraheonots yn hmimnr I onliu vnmi
# ngenle ealo gym tou Yem ond atrlreh yjm olodeeo
# t
# HI   c lelev oS
# aonu
# wotr enoeaw tond lah ln Iv In nPHetves roonghm
# ----
# iter 300, loss: 87.696299
# ----
#  yow we am af dm tea ingsoyo
# t 'Ierid ybeat dinh met hog tom of
# le rdiagd I ofing oc mnes clou oodile lol -o-rls
# fd
# Sflw -itnjv woe I hog wout foun ofirt avitgu we y afr ela kou'ldg Ies h'a eee waes
# ----
# iter 400, loss: 84.901495
# ----
#
# 'lue thet thmey siod'un jlwets'w'd h'els bou
# An al okr
# Whwar
# on wiyg orthe's amg acrar sou woer wlsoint lft hiad t wot's eoe doocs hhor
# Hamleind afve nom Idwhe twlrtserim teat uoalll
# I'ey sy ob
# ----
# iter 500, loss: 81.895247
# ----
#
# I PWe lweme doom fo tha lwer Aateag I omeres Iernr ao-ojysehouing tha Y add soou jYat orerene Ireoif fets fou yAut ay
# Puros hese es aetesot hom yeae igtherey he doong oneg alo poy me doom wime
# Yom
# ----
# iter 600, loss: 78.794058
# ----
#  f'n b depn whe lueb'u
# As
#
# Yesn
# oe youg itheanses
# whet hithl bellou
# Nelinds om ys whing ofrt ghel show
# Nings I met you lingartv medse'vakn bemyokn fes'u Ioringt I't aw ling ioowing t'rFs Nlom ll'
# ----
# iter 700, loss: 75.751222
# ----
#   oue boe
# Wele rof Yoot angd oun
# I've foon
#
# Wfve of mets
# Wham aor
# Where youyth
# Funthings fou deavn iof
# wale hiathet ayhakig owhoN t uat youg sothep
# ou hout eom Ie
# ge I mes you ind how
# Yplit af
# ----
# iter 800, loss: 72.781720
# ----
#  Fof fove
# gall fome kintharhitrubop
# Whe deoe worsy
# Ann I's whan
#
# Wels
# Hat iig wuYoknd afd
# Whrikng wot ronn afond I'ru
# vot yimy
# Avn wWels aml thor dimnd aoWs goe s weeed m al inI wind dol Ayf f
# ----
# iter 900, loss: 69.837709
# ----
#   i
# '
# I'l ou woa bat melsout dornskbeele sou thingam the wat out yous
# Pavet wothid selr I gows
# Hren omd ame youy fome anl a'me mhingt mese whout net lor donnd ts ing lou
# I dy leat ookl news sou aI
# ----
# iter 1000, loss: 67.058737
# ----
#  ing seind sot you
# What of nowing urran ow wfale tha thass for
# Whitwhore
# You beat wend betheot lowe lloret wof ring mhot lor bey alwre fere oove ho't oud ifs I ou mef vor IAtghot it ou I's tin wind
# ----
# iter 1100, loss: 64.338376
# ----
#  sind af the whar aw lofe
# I horknof fo neve won uod hint yurese Thitge r of ayw bow
# Whitt oo soml am ase kowjrs on no weene doun
# Ant awo
# I've all owr
# Whate I what ad lor
# I've feel teal fon
# Yomt
# ----
# iter 1200, loss: 61.789771
# ----
#
# Si
# g out alle
# And llintle I me wee eat do n out ehet lou
# At' I d ou ting w'os
# Aud out youn
# Ade I'me wite ar fo
# I litdeot hor nowesofe dl-ou
# Iouess cours
# Wenn on withouthis
# What anw I'm s'me
# ----
# iter 1300, loss: 59.319810
# ----
#  t ing pthe gon betse woave lloays methee thar Itlle that fow
# o-ong of thet am I'wings whom
# I lle yomyn ooT tooon ullow goe some
# Ands oI llou
# Whrethe ghor seom doP kinwas I've
# Whor I oow
# Aet set
# ----
# iter 1400, loss: 57.016593
# ----
#  nW fou soretime nee I
# What lit's It lou dounging wittiko' sory
# Whan I deon woat am wing
# Fou  out al eneoendg feove yeed I do nde lowing dowe
# Furt aloundy nomem juat me wallr
# gasit'hid wray ou sip
# ----
# iter 1500, loss: 54.733630
# ----
#   rithout alwu klouns youk
# And ou thet an or
# What aw the down I' ne foe
# Wall aveen gellsad oe thet ut fo-oking tliys oFrisit's rering  found bee t were ou ou'tling me of king bealing outsr rers sin
# ----
# iter 1600, loss: 52.648440
# ----
#  me iyways me some all f gor
# And hof coeb lou
# Whar thof
#
# What am I doing nownn
# What all
# HaSs lookin I I dowing I doe
# I'ls been I I doue
# I gor hen kitgon tilltu
# Whid wit alof
# Sow sor
# I lee lig
# ----
# iter 1700, loss: 50.514720
# ----
#  lithout' tAs son I wher outhat you
#
# Wey hora gat ne elray
# Whee I dlinghut's belingwingt gat nowss'm owr cof bue al roe thind of tilg thing thing dowits of some nen
#
# When of the ting  owhigs alwong
# ----
# iter 1800, loss: 48.742302
# ----
#
# Wall teow
# A'd thit'me mhand don
#
# Nor doey
# H-outhyu
# Yhen
# Whare of that you nove dow fome of twhf'ne
# What heseding of ting withoutha w it'us
#
# War ou tim ou toigt ou sor de
# I've all I wheres m
# ----
# iter 1900, loss: 46.819833
# ----
#  im fenphind I'm ef pram of tun  hott I will nY's fomn
# Noou sowrinet all do ig got toou
#
# Fal you
# Noe thl takit fer got sw bayou
# I leewi sou bell I sawl oon
# I me tell nowkind of tithu wevee fe ing
# ----
# iter 2000, loss: 45.205305
# ----
#  iysu doinn aow le of tays of know fellsod wingt am nowe inwon herrings fo-okit's
# And for hot ee loor I doing ferr oug of byokng kighout you ouoking doof neveou dooking I'm just awayd
# cheen ine afe p
# ----
# iter 2100, loss: 43.396998
# ----
#  n go lesr
# gue
# Fow bal or toe the the the the'r owr thott you
# And new hos thur ligor nofy whet serthet jut loayss Iokl outle oifs
# I cot ad withoutcal eolp
# Andea gon you gue'sings ror Nou serel out
# ----
# iter 2200, loss: 41.896673
# ----
#  ims ell hitrs
# I les le-one
# I-o-onde boou
# Yous
# What ae oue inw you d iog ow whnthe thimt eow bave lids of ting soor
#
# Fun yor I dou
# I loknd whof that wowlyidl-oe thet aw outsings IWhings I've beer
# ----
# iter 2300, loss: 40.329661
# ----
#   not rothnd deavt you
# And aels It's whithouttyor  in saveyn goe the gut lut you the thing tr of beeays it'r fou goiig for
# Ade srt horn
# Whot fe ou got jusour it lor somyt im It'lout you
# Your
# I'll
# ----
# iter 2400, loss: 38.983725
# ----
#  telwu
# Whene you
#
# Fae thun
# What hera yuoking fownd
# o-oon fou
# Ham same alw
# Whe ghet ind me iw lere shor
# Not aling jI thor beene hot've neme goks ingon
# There eheat im men llen beene lithe you
# I'
# ----
# iter 2500, loss: 37.535329
# ----
#  rs of -
# What am I'd fofl
# I'll wersay cor thoe tNd  I'me It's fikl for sert ne somesowe
# Andy dobe Too-
#
#
# Yam tamy
# I'm teel seFoking frele lee
# I llines
# I' widow berehid tide of dlor some ghene het
# ----
# iter 2600, loss: 36.358989
# ----
#   al com bue
# herethit's the thing fill set am Whetny fou
# Nom wimd foo inow cot's thee
# Tookingh gttls  It'l I do-bne ee
# Wher soret aw ref whetehe melle my loh out am you clls you
# Hame if I doee I'm
# ----
# iter 2700, loss: 35.066906
# ----
#   bhaad sern I ke wigd thingt outs reres I wat yow
#
# Fut am I doing wings t'me wone ellout you
#
# We looy
# Yime ar I go thee got a wonl hers als fr
# We som ounds sof bay
#
# What'us jut you
#
# Tal I doing f
# ----
# iter 2800, loss: 33.973199
# ----
#  e do whor tine rof me ne lot al I doing withou tigs ave lhave you some
# Whot's roknd you be ou thee me gow row
# What foke me then all arlount ine okhtt loing nowes foor beene owthing of ay
# I m now ne
# ----
# iter 2900, loss: 32.752971
# ----
#  dl one of fing sithau timyt doiiw'sigt ne hor ouet younby oor out ou tse
# I'd hor the that'me mend been
# I leat if I doing woren nowe downabe tous now lithior nom sof be gows
# And out am I doing mes d
# ----
# iter 3000, loss: 31.640128
# ----
#   oun
# What amy ooksid coks I's so-en ellind
# And all of thal ous out you
# As of mne else gone
# I'll tall domkon dI let
# fane you
# And I'm fakit sow bat al ounny sownd heos do
# Have als nou
# And cat ho
# ----
# iter 3100, loss: 30.587067
# ----
#  ame meething I'me t'me teo kit's mrend tim there looking without you
# You my deals beoay
# And alw lee s me goet you
# You thel hot'se
# what lit's tell dom
# Ham thot all of ne lout you thhe that noellig
# ----
# iter 3200, loss: 29.664980
# ----
#   hat al I leary door hotting rithour
# tTal I doing wone irhout you
#
# What'u I me me owt
# And  I me wilgs reou hitthid I dou
# And where jund ingisg wilg ting wnee out you
# Sows
# And oo-ound of thl t ap
# ----
# iter 3300, loss: 28.829160
# ----
#
#
# Weam you I'm of king some bend ther
# And all of the kir I'm I do nows that ill of uthinn doing without al I de
# Wha gut tine I've doos
# Nous
# Wher iow fo e't fime oon elling right now
# Avd doing bea
# ----
# iter 3400, loss: 28.006461
# ----
#  outlyu benok I m gout so ket lit lit me be nhe I'm leokis that you ne lows gof m nevehag fo  home
# Wen hat'se
# I'me thing I'm fo kYdor inowr
# Have bead cown ben ou ou gat hou
#
# Weh tall the then here'
# ----
# iter 3500, loss: 27.045272
# ----
#  I let you
# And hignt fo-ong or wayou ing without you
#
# Wame of on woitp lwakin I I've you
#
# Fun yere tene illous so-oono inn out am I'm fooring new something ntws fy lin ow sing nows got aw
#
# W
# dou or
# ----
# iter 3600, loss: 26.087299
# ----
#  e got ne
#
# Ways doing oor own do-ohhw ofr liowt lit s I d all of tI dithout you gern do
# Whot of ways uot no-one ehay
# What ame of withnoknd coe'se gfapyt let yoby
# And ell here doing witno t al I dou
# ----
# iter 3700, loss: 25.192840
# ----
#  e couks
# And veen looking witls thar you buttisigs tllit nows
# Have always
# And always mede fookne of mehn berne ow'my now
# Whathay
# I'm dowy
# Hell aI dhan hat a wof
# When I'w beene owhtad -
# Whone ben
# ----
# iter 3800, loss: 24.342284
# ----
#  felles
# I'm  ave eim see savey no-one ehtayI
# Whes
# Wheon I'me tha wenee foou ne lome feley eos
# Youl owryone gheneyo ll ehou beon yound
# Whing of yooknd sown fe dIad
# I doing sithind fo nove out ay
# ----
# iter 3900, loss: 23.523075
# ----
#   doing without you
#
# Wellind all ar outnoy of the thing
# What am I goe got of the things sI let you
# Pap
# So let deyo af sown
# Foe thins me ne lne
# goerind alwt liut ing fove
# And ano loer domes I've
# ----
# iter 4000, loss: 22.674439
# ----
#  rthind jond
# Whet ay mind alwu go grerthing dooeine whlt yu a littling wihgtthitI loae some ale
# What am I doung sor then yor nen
# for
# HWe thee yoaygnde
# And on goknd
# What am I doiighw ror nome hot
# ----
# iter 4100, loss: 22.130278
# ----
#   som somes
# I what am I do hithimd sown jhot nowayAnd lown grsithoat ne
# What aw ill al orethot yound ing wot's sime somess I'met you inw ores for wons nove benne lowne her ine whenos fookisg rerve yo
# ----
# iter 4200, loss: 21.394772
# ----
#  nool of sayouing arsad see's you the thind of the timl I doing without you
# Yoon you beend mee doow sithinds lowes hotende
# What af out re ko stale te it's been looking nome ou wind wners do
# You me b
# ----
# iter 4300, loss: 20.696555
# ----
#   thing dows
# And het's ne ortsee coos
# I let roit tooring waveee ou gurlou ind mend  fon
# I let of
# What am ou some sow hot aw for
# Pt am neve always
# What am I doing wno's I'vey
# I lor sown
# Fon Ir
#
# ----
# iter 4400, loss: 20.000867
# ----
#  one
# Who's werl hat am I doing tring witha I doing witl an erthind oing dleind  utt at am bell I I'y
# And fooring of the timl I ling withind  ithout you ban do-eYound  rome beene sown
# fown yoh thin t
# ----
# iter 4500, loss: 19.315875
# ----
#  de seme feveeride
# Whan I doing without you
# And all of the k
# thut heen lit's jwhnow Ir ltt lit lg at al ave benny
# What yon be lowss I'Wy noway
#
# We no-one elsay
#
# We nowr homes somes been henraying
# ----
# iter 4600, loss: 18.752242
# ----
#  rl loat you in whet s ne fon yow thing wrene no eos sovey no-of bees how le ersoye yo l tere you gat am I doings Ithind on eing me e's I'lliss if I've epking dowe
# Twoys or outs oowing f'r lthat ig th
# ----
# iter 4700, loss: 18.310217
# ----
#  ve alw beay of may
# oI thing f't let you coone
# What am I doing oWhing I'ways no l ferpy bat imt alsays been leor deall something tere tene
# I'lle goes ire se'l juthut al hat you in where no-one else
# ----
# iter 4800, loss: 17.757689
# ----
#  of the tis then yone yofe heat hot indo ind of
#
# No thing what hon ying nteayt you
# Prat outlind or sof mnd iso eray Iad cat am I doing wht you
# Abd all mes rithous
# Have alwne
# Wher I doun''ll I've c
# ----
# iter 4900, loss: 17.201318
# ----
#  I'm fomy hitways af ofs
# What am I doingw
# Whe wI'll you behs ihlwus
# What hettis sof
# Yamesor doorside slopr
#
# Whot hot am I dobe
# And fooking fere lide you
# Yamethisn
# I's beann lert hit's met hetno
# ----
# iter 5000, loss: 16.796676
# ----
#  doing without you
# And now lee ouryoutsignt dooking for
# Have alwsor somesyowhing for
# And ale you
# Nor julsjy ave things tI
# I lot hoor been you
# And of oue
# And always on thing astang dor
# And all o
# ----
# iter 5100, loss: 16.197223
# ----
#  u
# And all of the things that no one else keing what you do is I'm foend ins sen'ne where s allone'r faklisd feon oflme fokn het co eY I'm falling newh dome feme ale eo e there ing without your
# Ast a
# ----
# iter 5200, loss: 15.682997
# ----
#  eny leigs I's
# Thotr oonny
# Well tere
#
# Well me doing newe
# I let youe'sid's I'm that all of Wanl heot Nos yFwenny
# What am I llos
# Wen same always been here outs ar leeey
# What am I ele
# Hat am I doi
# ----
# iter 5300, loss: 15.100235
# ----
#  hat am I doing mn else fo'l oweyor doing without you
# You wiml af chot you
# And of me fuono ing wtnd goe
# I len you
# I weele rlee
# And ferof down
# Fove
# I het you ndow sithay
# What an wone elwu noelr
# ----
# iter 5400, loss: 14.708014
# ----
#   bThe wing bear finne
# Whap I dalling now
# I'll mery of mhndeav' utamy somele goe nome hoowing wcave you
#
# Hat am I doing without you
# Have awrap eam I dok go pI mldokn
# Who't het limy been heren foel
# ----
# iter 5500, loss: 14.229550
# ----
#  wI lee
# And
# I'll I le got a wat cod bat am I doing
# We gat a littlig tid ther
# What am I doing fithrings I've beave always bene haway ur ouls fo
# how
# I'm I doing without you
# And all if I'd fin I'm
# ----
# iter 5600, loss: 13.874786
# ----
#  le I I'd tim I do
# Your do whor ther ind  loorytline
# What seme you things that no one yom thor puomy reres I'm lorery
# I'vee eo lit's bee int sou
# I lettle foe g fers of I'm I do in wone
# w'llitt do
# ----
# iter 5700, loss: 13.415265
# ----
#  whar thany somehaw I'd
#
# We foes you
#
# Have ar af wabeaysuyou do
# Whathat am out you
#
# Whhe oifd all of the time I plit leat af one
# And all here doonn
# Yoat im sapl igh tts do
# 've some lo ese I'm fe
# ----
# iter 5800, loss: 13.188784
# ----
#  hout awn foo ho wayou
# And all of tol tam juttyone
#
# When
# Who the thing withayy you things that alw mr I'm leakyonndownde it lon you
# I peat ae
# I'm Nor
# And all of the time simes dlle fees you thing
# ----
# iter 5900, loss: 13.006015
# ----
#  l I've fome how hing for
# Have yow bhoneeys do el hakn you thingst's juoby nook
# And all that am I doing w'thinn you do
#
# We me wihes I'm hoor
#
# Tveet so let It bhere I'me that avone
# I'll me mindh It
# ----
# iter 6000, loss: 12.773504
# ----
#  on you
# And al I dou
# So
# Whad I lee gowising for
# What am I ke
# And all of my doond
# Have men yome
# What am I doing without you ind
# What am I goe
# And all of the going foknd
# Whathay
# What am I doin
# ----
# iter 6100, loss: 12.439610
# ----
#  orst lit yok
# And all al orl's
# Iam kis'm jutay
#
# We mu soepy
# What am I doing witthout
# Ham teve you I'd fing little I've me ne
# I'd I doist im wutsimt I wI doe womps do
# I's f'n ben eot nn ele someh
# ----
# iter 6200, loss: 12.115974
# ----
#  aveays mnee ling thar
# uave always beans of me nowben oon
# I'llite of been juone
# Whot me bean yowt lere the dooling some fell of me soel of the gif's ut lit
# wayssars ave cend is I'm
# I lleny irlwatl
# ----
# iter 6300, loss: 11.631913
# ----
#  oubyide in you
#
# Way sone
# I'lle your siwws goe
# And thay I hernd ing wnell her
#
# uat if right nows
#
# We gon I doers
# What am I doing  itthin's been fand all of the things sI ll you fiowht's foe
# I le
# ----
# iter 6400, loss: 11.324235
# ----
#  on yound ous I'm fave you
# And avoul I wontthe goe's fo ling do 'ths wing worl eon beele fel hen foonby
# What sown
# Yoon where own
# Frer I'm leoking right now
# And all of the dime hete swane
#
# Weal at
# ----
# iter 6500, loss: 10.911431
# ----
#  I'm your
# Twaypy foe
# I'me I doing witthot litt re rou
# And now been lore
# I oor got nolis soresthings 'fen
# I'll some howny
# Theress goor
# Asd all thind Iom beed here some he whe thing without you
#
#
# ----
# iter 6600, loss: 10.661559
# ----
#  ou make me ketpe worl I goney
# What reing for I'm I fakn I me mifr all of
# And all of the wiswing nor
# I lithout you benny
# What am I doing f'wn what am I doing without you
#
# Fun you
#
# And avoknd ligw
# ----
# iter 6700, loss: 10.251544
# ----
#  de I'mn you
# And avound iset'l wave you
# And all I'm ay
# Yave you
#
# Whot al of
#
# We been llres
# What am ou thitg tray
# I let m nee shaveays you
# You thing ror thing withind
#
# Watls do lno-one el's do
# ----
# iter 6800, loss: 9.943413
# ----
#   fone het'le whe gu ther
# And all of the things sWekl I wabe no on fo hee lisw lloknn oor or sown
# I'll tell you thittle I doing without yod be me sike you
# You ther sooking for
# Have always been loee
# ----
# iter 6900, loss: 9.537959
# ----
#  e co-one now lo-enn eos thing nown
# As sor
# And I'm fo kno
# Whaveay feen eor somety soing I's feon leoking for something
# I'm llres
# I littlint am I doing sitts doing wind
#
# What heen just lite an sow
# ----
# iter 7000, loss: 9.300435
# ----
#  looking frer lire som thet am Ia lit's urer doing for
# Have alw no ehe I've been looking for
# Have always
# What me fave al ayound iisg nee'N sow
# I ef what noel
# Weel I fou in what am I doing withor d
# ----
# iter 7100, loss: 9.101202
# ----
#  ldyoling right ne what am I lokeling that am I dou
# I leat is sor things that am I do in I've ine here oint neweynd of the ghat hookind hor
# Have all nou grrounthing new
# What am I do ing what abe ghe
# ----
# iter 7200, loss: 9.141054
# ----
#
# Pray aveay of the tl out reaveying without you
# Have men
# I let you
#
# Fur hat lithounde lide It's you
#
#
# Welle gotts ne ling right now
# Praying thee you cownee if oun
# I let you ing I'me tell you the
# ----
# iter 7300, loss: 8.943923
# ----
#  fit's do
# Havpy
# Foe wonl you thint se pYave you
# You withay I goas
#
# Tave you
# I won't some thit't ing thing sithing I's ong
# What am t lee
# And of the wint's fores
# What alle
# What am I doing witll
# ----
# iter 7400, loss: 8.840200
# ----
#  h that al I doing without you
#
# Fun you
# And all on gat am I doing without you
#
# Yone else goes
# What am I doing wigh ar iow yow
# Prays some feo
# Hepr sows
# I len you wim thot you
# And all ow sorl
# Ha
# ----
# iter 7500, loss: 8.619440
# ----
#  some femp you
# And all of thittha I deay
# And foos
# Have always doo lime of that ame lets atha d av'me foeec new
# And all of the withing t'm rarlin lookisgt'nd wof
#
# Wels wrere of my goe
# I leall dore
# ----
# iter 7600, loss: 8.413544
# ----
#  ings make ne
# I'u tim ting wone
# What am I doing without you
# And all ow ther litl al I gout ise
# I lit you
#
# Wayou the rithout you
# And all of the time I'm looking for hound is that ho le m hat erey
# ----
# iter 7700, loss: 8.099109
# ----
#  it's you
#
# Furs that ne lot some how
# You will andwnnd of the tim I elsitlind the wne's foun yiml ignay
# Foe gowr oowing fitelin I dore
# I letty de ing whot doing me dooksthind oow you
# And no litws g
# ----
# iter 7800, loss: 7.924822
# ----
#  tim tarl ow
# And all of the things I've been funry
# What thaywing wavehe thing f rid I'm faliitt's rere cunmy
# What am I doing without you
#
# Well it's felling atthe witlind aywabs al oun els of the gw
# ----
# iter 7900, loss: 7.667865
# ----
#  by
# Wehe we lwarst lown
# You wor
# I leay yorlthing wings t'm junderllere feind out you be lit am I doing without'id aveay
# What heene here outsidlitgse gof ne lhthid med eow he ghere some al't reary b
# ----
# iter 8000, loss: 7.469451
# ----
#   without you
# You hooking for
# Have always beeno foe hing rit's feeling rir's feen elou thingw lomeone
# Who's beade I've le mis' for hitts mresing
# hat some al that now
# Yeor dorl I What's eround oikl
# ----
# iter 8100, loss: 7.246973
# ----
#  g down
# You wilgt no-one else goe
# I've bat domy
# fal ting mt am you
#
# Well that am I doing without you
#
# Took our of
# What I me do ehten ehen
# What am I doing without you
#
# Teok sownd is Irell I'm lo
# ----
# iter 8200, loss: 7.112677
# ----
#  lse goes
# Whee cen lit's fel lithout you
#
# We gat ad beat am I'd ming fleay
# What am tha wilbt thay
# What am I doing without you
#
# Wesou
#
# We gor our own
# I'll tell you
# And llways beas sove ees
# I le
# ----
# iter 8300, loss: 6.915363
# ----
#  t lou
# I'll tell I doing withoutd dowe
# I wake I'my am thit me munde I've you tho tc n Iad I done
# No sHave always of me fo lint am wor'm bakl thar
# I's sere'ne els doing for
# Ham tam sore tler
# And
#
# ----
# iter 8400, loss: 6.773792
# ----
#  wrele lot phat it all of our ow
#
# Pe le cout s ing nlways bene something new
# What am I dlars or been lit's me hare cou
#
# Wa lot no one else goes
# What am I likl you comy something alwing wot's dow
# I
# ----
# iter 8500, loss: 6.595031
# ----
#   without you
#
# Fun you
# You cuthud I'm llery
# What am I doing without you
#
# Well ing on eof been I leave of ou's what au mnd eowhnde looe fo ln ell oing womet someone
#
# Whe te l arlout yoing feres
# I'
# ----
# iter 8600, loss: 6.373806
# ----
#  hat you ne lithing des
# tays urerone
# What am I doing without you
# And all of the things I've been looking for
# Have always been het this swave you things that no one elme when yo-one elwu
# I me cooki
# ----
# iter 8700, loss: 6.155145
# ----
#  hing newny
# Fon gigm outayouing fou i
# And I'm llay
# What am ayou then you
# And I me all of the wor
# I leave of fone hewny
# What am I doing without eowibs been yout you
# And the things I'mllt men els u
# ----
# iter 8800, loss: 5.951798
# ----
#  n
# I'll tell yor sooking for sometyidese goes
# What am teings kroos the gn where no-one else goes
# What am wneth ony
#
# Wen I wathat beane foe coorings It's m hethay
# Whapt you
#
# Thor door
# I littl awi
# ----
# iter 8900, loss: 5.765210
# ----
#  hings I've been hore no lhave of been los things that alle I leat nown grastays jp ou mu gort no-one else goes
# Whan you thing t at sone is ou our outside of be behny
# What am I doing withoutd no one
# ----
# iter 9000, loss: 5.588594
# ----
#   a litts do
# I'm the thing new
# Wheet of
# aveny meling righout
# And now
# Wave all of the wing te
# tele I'm I'm fell igw rere ther
#
# Well I way
# Itrlet le king now
# So ghtt you behing pre
# It's feeling
# ----
# iter 9100, loss: 5.541679
# ----
#  the gaves you
# And all I'm faneing methint he things that no one else goes
# Ween I'my arout ne lhay
# It lit outsid outtyd I leatling fit's feeling right now
# And all of the things I've been I me door
# ----
# iter 9200, loss: 5.586300
# ----
#  t youings the thing rigs myoulsimlt ne when let'sing alwing for somethyokit's reoneeyowis't lething fow
# Havedon w'hon my goe
#
# We ks w
# Whon
# Noos
# And all of sove't foe
# heof
#
# What am I dlays
# Wean
# ----
# iter 9300, loss: 5.651377
# ----
#   hot of
# Weal Iamething we s avs at am I doing fer outse elou co-one
# No sIt litwing mnownde het lin I d ave ne lethot ne lom fanleo fonl wo owind
# I've beone
# What am I domy yor something new nomeone
# ----
# iter 9400, loss: 5.797716
# ----
#
#
# Well how lo-o hot aa world ofr ld all
# I'll tell things I've beene somelde when
# I leay ju dnees
# Whapw babeing thron
# What am I doing without you
# And all of the gu gokiting mekn way
# I'll tell yo
# ----
# iter 9500, loss: 5.985144
# ----
#  een looking for
# dous
# Whot sewe
# Ham iing withaut ad I''s reene lookings It's do is what af out uone go-one else gowone
# What af ays
# Wam lith oe things I've behe mat you
# And all of the things I'm I
# ----
# iter 9600, loss: 5.902360
# ----
#  ys I've bethe till you ne hithous irwou tilgt no-ofe iw's rele down
# Whan I doing withut do else
# I leays fou beos dooring whaayt is thee you thingl I'm some
# And kelowsine ooking fown
# What doey's fo
# ----
# iter 9700, loss: 5.761882
# ----
#   all of the things what am I doing without you
#
# Wels thle you
#
# Furt al ave htt l I doing without youling fooeing what I dooing foo
# You wof
# I'll tell you things tha gittha worlit aveays been litt a
# ----
# iter 9800, loss: 5.570353
# ----
#  ou will het it I goe
# I lit hon
# Asd cook
#
# Wen waveay
# What's teu fu
#
# Wernd reon I's ripw sool oueson''
# I'll I let you in what's fell it's rithout newn gows
# Yeat away you gows
# Weap thathit's tray
# ----
# iter 9900, loss: 5.384074
# ----
#   I doing kithout you
#
# Welle doelg ig satlle
# When I'm bakitlis serehor ther I founde lot line outs eron ou world I'm looking for some
# I me fill sh ppa sithout you
#
# Took
# And fo lee's I'me thar some
# ----
# iter 10000, loss: 5.218643
# ----
#
# Prabe al I'm fad ben whe r ove
# And goen'yis sF knw
# Whot sown
# I'll felling down
# Ther tell I wou
# I let line
# Ithu tim timt am out het's dowing wnelling for
#
# Tlokn
# FWel I dooking fo kings I'm loo
# ----
# iter 10100, loss: 5.061383
# ----
#  of sithout you nin ore's make sowks dour
# Prat so l aves been looking fore somehay some hetrsoreris't leayy's that no ou worll I'm foing wat'se wo litways if out let you do
# Whot's what am medd Iou th
# ----
# iter 10200, loss: 4.944572
# ----
#  And all of the ging without you
# And all of the thind uthat no sod lot youing for
# Have ayou
# And now some benhe I'me I'm foe he gotr liteine where outside of things swall I gor
# And all or tam mind t
# ----
# iter 10300, loss: 4.823738
# ----
#  nows
# I lways for sthis somesterif
# And all of the things I've been foow
# Pray I'm t at no eano loo shers you
# You make me feel harls me beele te's somethee
# What am ou the wo ligw now
#
# We some bead
# ----
# iter 10400, loss: 4.689734
# ----
#   eow  fave al aysays been here outside of my door
# And ave one else knows
# I let you in what am I doing without you
#
# Took ou mind now hat ho ay
# What sown
# I'll tell you things thay
#
# Wa lit's do it
# ----
# iter 10500, loss: 4.536861
# ----
#
# Yout se krows
# What am I doing without you
# And all of the time I'm looking fokn yown
# No fnd
# Whoor iow thind nel outside of watll the tI ll ere hthay you things that no one else kow somehow
# I wone
# ----
# iter 10600, loss: 4.376934
# ----
#   doing without you
#
# Took of our own
# I'll tell you things that am I dring without you
# And ave of the wings I've been hot al I'm looking for something m't yound ise ere thing that some hor
# Have al a
# ----
# iter 10700, loss: 4.226123
# ----
#  f dor the te s aveays you things that no ong witd always or may no let le way
# Ann
# What I found ookind
# I'me yores
# What am I doing without you
# And all of the time I'm stha' you sings that no one el
# ----
# iter 10800, loss: 4.077744
# ----
#
# Have always bearl owny
# And all of the things I've been looking for
# Have always been hethay illoue yous
# Whea s ele of our no-obe orlse ksom ralling firlthindy
# Whand I'm fakl for that avee st's wn
# ----
# iter 10900, loss: 3.947052
# ----
#
# Tome ue lo-oo iow
# I lin
# Have fooking for
# Have always been looking for sing nowond
# What am I doing without you beo if the rlipg t le doik's orethiny
# It lr rind somehow
# thayting me me eo le do
# W
# ----
# iter 11000, loss: 3.821996
# ----
#   the thown you fome here
# I let you in where hot this slings freey I'm falling dove he wut's allis then you
# And all or the things I've leony
# There's avee he thing for
# Have always someone who saves
# ----
# iter 11100, loss: 3.703869
# ----
#  one
# Who's just liae all one else goes
# What am I doing without you
# And all of the things I've been lhot im I ke eow
# Whing for
# Fun you
# As something new
# What am I do ig wor'm looking fo nowl the g
# ----
# iter 11200, loss: 3.583795
# ----
#  ng
# I'm I dlere'ne whot ne
# What he thing derl hat ad I doing without you
#
# Well it's fays meen hethat some ou mat all of the tim I nou
# I let you ben el It'l wives yound is been lokes
# Whan yor the t
# ----
# iter 11300, loss: 3.480030
# ----
#   hon I'm llre out am okngs I've be me mabeber I've benne howey draveay doing withoutd felind it leh thing withu dors do houn
# Whatha eithitgs t'm f noring
# I'm jutt domehae I
# It lit our own
# I'll tel
# ----
# iter 11400, loss: 3.376984
# ----
#  ve always fonele of ou time tha ted ever foos ing reten eow somese Whon me goes
# What hou no ll owhsut's feeling righ tr oHays jvee
# And all ar sthe dime
# I met youinims It'm foe chor
# And I's wone or
# ----
# iter 11500, loss: 3.330881
# ----
#  faves I've been I leat im It pfaywn gr lind now loae't feeny else gorl I wojnd mitling tt m ofe
# Ann Iad
# Yeen I my ine what ho ke gony
# I'll you thitgs thay someone who sou
# I won
# I'll thit yo lle g
# ----
# iter 11600, loss: 3.557289
# ----
#  thee do
# Weve els wet no ppr some me gowny
# What semeone
# I'me the things that no one else knows
# What am I dou
# I'melind I's frese wheres ife gt likn gowny
# There's always someone who tt my dore no I
# ----
# iter 11700, loss: 3.786138
# ----
#  doing without you
#
# Well of men eos things thaed you
# You wor
# I let linn ell out honey
# When I'm fal ing for
# Have always been I guetnn
# Who le what you
# And all of the tell some
# I let you iu foe
# I
# ----
# iter 11800, loss: 3.735952
# ----
#  u
# And all of thitl aam lowny
# Who's orest's reey krout
# What am I doing witl at leiny
# I lit am I doing withous oreson my mide nowonn benee foory lot re hittline of our own
# I'll tell you in where do
# ----
# iter 11900, loss: 3.690039
# ----
#  ings the wous low
# Well it am I doing without you
# And ave you tim teu tim tere you things the ritga sims all of been looking feo ind sevey lround
# Whang me ting thitthind nor outsing thit's feeling w
# ----
# iter 12000, loss: 4.262183
# ----
#  hat am I doing without you
# You thign thl tere whethind
# It's aveay cooking for
# Have always somehow aNr outside of ou the gor
# I llt se pcave all of me eere outside of sidws 'I upry
#
# Wen hit's me th
# ----
# iter 12100, loss: 4.495172
# ----
#   behind
# It plays on me mind you
# And all of the things I've mebee what al I doing without you
#
# Wels thre I'm loteld of our own
# I'll tell you come around
# Yome let thing
# Prayou ilg ne ling right no
# ----
# iter 12200, loss: 4.398182
# ----
#  where no-one else goisw littlin wurdoing without you in where no-one you the't aveays shavpying wneey
# To lresen men ert'ne where nomesdellets of gor the gavs frehne elw been juttides ytend
# And nos
#
# ----
# iter 12300, loss: 4.315881
# ----
#  l heres gren you thing new
# When I'm I I's I'm let you do
#
# Pe gwaps thar some de lithou thigts nowny
# I'veays of my go-ou in whe't sown yous sowe seres
# What am I doing without you in looking dor
# Ha
# ----
# iter 12400, loss: 4.182007
# ----
#  else knows
# I lot thas
# What af out you
# And ave leay bern It laekno
# What al Iam cav' no of me feer hert leis afl ing woays foel that it's true
# Nooby bhot ma ead thin I leay
# And you deround
#
# When
# ----
# iter 12500, loss: 4.043781
# ----
#  hout you
# And all of the thingsedown you
# You make me feen goe things that no one else knows
# I let you in wif's
# I ue else
# I eoke
# I lethe deing litthne
# No
# the time I'm looking for somes go
# I let
# ----
# iter 12600, loss: 3.873148
# ----
#  l you things that no on wirls yound ing fere felle doepr ing wrre he't sows
# 've door
# And all of the things I've youlbyund
# There's always someone who saves me
# And girl it's you
# And thoon yomllers
# ----
# iter 12700, loss: 3.733098
# ----
#  oney
# What am I dI loer
# I me hers of soows do
# Whe tha wave one
# I's that come yow life ca-one owhs I've beene of mihit so-oything new
# Whot am I doing without you
#
# Took for gring wof my no-one else
# ----
# iter 12800, loss: 3.576698
# ----
#  orld of out im ted is that am I doing without you
#
# Took forl I ke so no lings mI you
# And all of the things I'ml some aroun yof the t little wor thot no one you things I've behe mu cave ying nown
# An
# ----
# iter 12900, loss: 3.455485
# ----
#  I'm tha
# Son fe got a little world ofr of out ad
# As outside of my doon'yiing ter inne rife I fouing
# When her outsing new
# What am I do it right now
# Praying the things I've been looking frwhing fit'
# ----
# iter 13000, loss: 3.318033
# ----
#  ouind all of the things I've been looking whathyowing what you do
#
# We got a little worod foo
# Yous
# Whot' no-onne shar set's what ad me fooknof cavebe hert you things mend jus I'm falling down
# What
# ----
# iter 13100, loss: 3.211924
# ----
#  am looking for
# Have always that a littla world of our own
# I'll tell you things ther
# tell you thit's ther  uttling down
# And fooling ners someone
# Whow yld eveey
# What am I doing withind
#
# We gat av
# ----
# iter 13200, loss: 3.087720
# ----
#  I'm just Ies sevehe things I've bedne I'm lit'l  aveays of the things I'm just hrony
# No buts or mays found oone
# Who't awsaes now harl outtine of dersidllsone
# I leave beonof
# So lethu allit's do
# t'
# ----
# iter 13300, loss: 3.002994
# ----
#  ou make me feel funny
# When you things I've been looking whand
# What am I doing without you
#
# Tlokn
# I leamy of my beone
# What'me oow no ll oreheo
# I've you mat am hon you magl ou maby iwnon watll tea
# ----
# iter 13400, loss: 2.905090
# ----
#  fe that hethind you beam foney
# When
# Wehl I reony
# FWe tha
# I bead hor domehoe things that no one else ghred if out am I doing what you do
# I'm I doing without you
# And all of the things meen eon you
# ----
# iter 13500, loss: 2.952422
# ----
#
# What yownde
# What am ay
# Weno lett at sode
# Who'r just realising wiknou thiggs that no one else goe
# I leave you behind I's fou
# And somehaw het yine foo
# here no-one elsesthing we
# I'm jus that ay
# ----
# iter 13600, loss: 2.932362
# ----
#  l it's you
#
# Well I gout semehows
# Wen foing withau ihite out soor
# And all of the time I'm looking for something new
# What am I doing without you
# And all of the things I've meleo looestell I've been
# ----
# iter 13700, loss: 2.883077
# ----
#  foreses gras I'w rere
# And all of the t'm It's do l
# 'le dlout yoorlin worls erout you
# What ahe yoone elsome
# For setrloy been here outside ne lead of the will understad avees
# What am I doing without
# ----
# iter 13800, loss: 2.790533
# ----
#  ofe gitw now sithout yound
# Yeon ees you thing artayl
# I eony
# Whe got no wher that it's t'ue urhat you nowhone
#
# When I'm falitigt It'm here hooking loke
# Hres that hetha you things that no one else
# ----
# iter 13900, loss: 2.722531
# ----
#
# And all of the wings rou
#
# Wello rothing nwreon I'll owW
# And all I found out hereing down
# And fooling aroungy
# Wean I do it sor thind out howays
# When I doing what you do
#
# We got a little world of
# ----
# iter 14000, loss: 2.634640
# ----
#  for this stam fall ither dor somese go-our do
# Whee serel I dee's worl
# What am I doing without you
# And all of the things I'm lone yous
# I'veey
# What am I doing without you
# And all of the thig wavea
# ----
# iter 14100, loss: 2.572021
# ----
#   here foe
# I lit ten wilgt somy
# What am I doing withous I've al oings I've been looking for ind of our own
# I'll tell you things that no onn elle goesc I'w that am I doing without you
#
# Well it's do
# ----
# iter 14200, loss: 2.499749
# ----
#  outmy al ior you
#
# Well it's feeling right now baby somehing rore
# I
# I wIt's that lofe hettlind
# fen here outside on wornd for something new
# What am I doing without you
# And all of the the ginw make
# ----
# iter 14300, loss: 2.434199
# ----
#  ing dorl dows
# I leave you
# And all of the thit's famehit's areing what you do
# What you
# And all of the things I've been looking for
# Have always been hern eo
# It's feeling right now
# So let's dewe h
# ----
# iter 14400, loss: 2.355897
# ----
#  at it's trabe foe
# I leave you behe tha will some deor something new
# What am I do it the wing withony
# What at some around
# Yoout yous
# Wehe things that no one else goess I've behay
# What am I doing
# ----
# iter 14500, loss: 2.296565
# ----
#  the things I've been looking for
# Have always been herend is'te linl you come arloun you cing neway
# What am I doing gor the thing ter cam thingse goess found out's weeling do ith
# Whad I letthit sown
# ----
# iter 14600, loss: 2.227773
# ----
#  d is ove
# And all of the the
# I leays someone who sadwing wor outside outtid I kelwhone yom somet doist sadess
# What am ou the got a little world of norlsome alwayon doilgt nowind wignt sowe
# And mest
# ----
# iter 14700, loss: 2.174579
# ----
#   without you
#
# Funt of the tell tere whon'y no-onn orhut al sof ous nowe
# And I here haw you
# And always been heray
# Yoorl or the wI goreave le eone ghend
# Whe ght aw sewe feos domehne
# You cums been
# ----
# iter 14800, loss: 2.115228
# ----
#  g
# Htha d do ind I'm fouing down
# There's always someone who saves you
#
# Funny hhhe
# I eeee foony
# I've beree I'm I my door
# And all of the things I've be is sof
# And yoor somes now
# So let no one els
# ----
# iter 14900, loss: 2.067057
# ----
#  lse goes
# What am I doing without you
# And all of our own
# I'll fellibe all of bee gowing for
#
# Wee sthat no one else knowss
# I let you in where that it's true
# No sursing that und you come awo sine y
# ----
# iter 15000, loss: 2.015898
# ----
#  t so let sing that ahou things that no of hitine I'm I mabe ne lo ayt llee
# I leayoy
# Wave forl here inny
# What am I doing without you
#
# Well hthay someone
# I'wn Hallings won
# I let you in where
# I li
# ----
# iter 15100, loss: 2.021533
# ----
#  let you iowisgt nowing withn all of mhn yor
# And all of the gings that ihe rett you donllills drind I'm litha y I'rl I'mehne ll oPrount littsad ount beee oust iw lif out uon
# I leayings gow
# Praying t
# ----
# iter 15200, loss: 2.266184
# ----
#   wiht'nyt nownnd is or our ou thign I'll Itl eap some yownyg
# What am I doing without you
#
# Took for granted esound wave newind eing new
# What am I doing without
# you
#
# Well afe foing what you in where
# ----
# iter 15300, loss: 2.723464
# ----
#  hat no-one else ellliteling sitl or thing that sone yom of bee gon w'llings uthnd you wings of
# And you thit's that alw of bee no oon yo lirw no-ou worlm ooknd mel orlthe will underldoin's II me feel
# ----
# iter 15400, loss: 3.030020
# ----
#  hing we gatlme mehory
# I meny
# Whan I doing without you
# And all of the tame fall ago It llerl outsy kit heray meen forking I'd beat tene
#
# Whe watlme been outsing lites what he kno
# Whon you seeling
# ----
# iter 15500, loss: 3.267867
# ----
#  n
# I'll tell you things that no one elseors do iI's falising what uomy
# oun
# For serliting wher
# I me goe
# I lit s what al I guave you behis somet ihe ne lithout you
#
# Well you things that no one else
# ----
# iter 15600, loss: 3.200098
# ----
#  hings I've lehings I've aling atray Iome yow he
#
# t'll I'm It'me foe hit's I'm loue hooring down you mr ther something new
# What am I dou
# We lwa gutt at sofe ihe ne light now babe fo le elwoking for
# ----
# iter 15700, loss: 3.128240
# ----
#   a little world of our own
# I'll tell you things that no one else krovpe cous
#
# We got a little world of our own
# I'll tell you things that no one else knows
# I let you in where no-one els oFh thay yo
# ----
# iter 15800, loss: 3.014384
# ----
#  my bean aam me beo-one else goes
# When you come around
# Yee harlmyt you
#
# Well I guess I'm rit's feel it's feeling right now baby somest litthe tim loe time I'm looking for something new's cous
# I's w
# ----
# iter 15900, loss: 2.884734
# ----
#  t this whings that no hore do
# It's feeling right now babe how outside ne out you thing now sithing now sowny
# I litwnon fife I've you things It's I'm looey dlit's felling arways someone
# Who's justin
# ----
# iter 16000, loss: 2.772010
# ----
#  ays been here outside of my goe
# I'me meele for things that nomy you
# I got no one elllet yomything newn
# What am I doing without youe
# And all or the gowst doing what hooking for
# Have always been he
# ----
# iter 16100, loss: 2.656208
# ----
#
# And all of the things whan you cam here hers
# What am I doing without you
# And all of meline I fouy
# An yout ne
#
# We lit hon els or sor that ad my door
# And all of the things I've behne beene lomeon
# ----
# iter 16200, loss: 2.557149
# ----
#  een here outside outside ohht nd ono
# Whan I mabeing ave
#
# Wenonite leany
#
# We got a little world of our Hown
# I'll teoo some are htt liteld the whigt anm looking for sometayou bee own
# Weon foon iis
# ----
# iter 16300, loss: 2.455500
# ----
#  y
# It's feeling right now
# So let's do it right now
# Praying that some how
# Yhor
# And newn gr lit sing nownd isl here no lets fers someone
# Who's jutting down
# What me feenn eos benone else
# I let you
# ----
# iter 16400, loss: 2.365296
# ----
#   all of the things I've been looking for
# Have always been here outside of one elways
# ho lnt le rets on beene oow hers down
# As something new
# What am I doing without you ind
# What am I doing without
# ----
# iter 16500, loss: 2.277001
# ----
#  ou will understene I's I'm rere hers
# What am I doing without you
#
# Well I guess I'm rere ou somethings  It lite cen's flen you mind of ine owhsing
# I'm just realising what you do
#
# We got a little wo
# ----
# iter 16600, loss: 2.198518
# ----
#   I doing without you things that no one else knows
# Weal I gout no lee some am  aYo frell someone
# W'l tenoyine where of
# Fon goer you doing fight now babybyou
# And always been heat some ne litelitway
# ----
# iter 16700, loss: 2.119963
# ----
#
# Prays that ne
# Whathat ame
# I'll that some ne life she
# Somese I'm jus than you ting for this swanl of ou been lisw seal te le got no lifes nowos now
# Yall you things that no one elsoflin looking for
# ----
# iter 16800, loss: 2.050582
# ----
#  no-one else goes
# What am I doing witls do
# You come afo ng withing new
# What am I doing without you
#
# Well I gueth ow door that it's true
# No butsou come around
# Yeae rif thind of then
# What am I doi
# ----
# iter 16900, loss: 1.981388
# ----
#  And all of the things I've been looking for
# Have always beee happy someone
# Who's just life I fe ine of mend for gors
# Fun yous
# I'l hat'u
# I'n  at line where no-one else knows
# I let you thingst now
# ----
# iter 17000, loss: 1.919139
# ----
#  nows
# I let you in wonl of thr't lee
# Ihee your
# Wham seer ing that it's true
# No buts fe gars ar outsid the time meling right now
# And all of the time I'm looking for something new
# What am I doing w
# ----
# iter 17100, loss: 1.858446
# ----
#   it's feeling right now
# So let's do-
# Whorl unnee
# Yol warlit's the things I've batising nowe dookings no-oy doorhjn
# And all of the time I'm looking for something new
# What am I doing without you
# Yo
# ----
# iter 17200, loss: 1.803480
# ----
#  things that allere
# I'm rit's feeling right now bab benee thar someone who sad ound
# I grareing for
# Have always you bat af som thot hoo-one else knoms of my door
# And allme dlokn
# I let you in where
# ----
# iter 17300, loss: 1.751837
# ----
#   doing without you
# And al I dou
# I let you in llerehow
# And fo life lit's the wilwoy uthhe
# No bt ll you foo
# that aN  ar out you
# So lrou some mene is's wreone
# Nooknowl or
# And all of the time I'm
# ----
# iter 17400, loss: 1.702504
# ----
#  ok own
# I'll tell you things  It do eliigh tha ting what you do
# I'm just igt al serl here's avee fe ghthh truoning  It'm time hone
# I'll tell I's unw lot al I's mabe gow
#
# Weas someone who sor tel fe
# ----
# iter 17500, loss: 1.658891
# ----
#   something neway'h me ceor hert thn wing ret do
# feon me
# Have always you tam tim tead you things that no one else knownd in way'u serllistinn eleaylisgt no-one else fobe all of the time I'm looking f
# ----
# iter 17600, loss: 1.624445
# ----
#
# And all of the things I've been looking for
# Have now honey
# What am I doing without you
#
# Took tin I ppays no-one else goes
# What am I doing without you behis sere's neve goes
# What am I doing witho
# ----
# iter 17700, loss: 1.782170
# ----
#   the time I'm llokind is there no-one erous
# No bathay
# I'll oulbad
# As been looking for
# Have always beel outty
# I'll tell you things rou
#
# And all of the things I've been looking for
# Have always be
# ----
# iter 17800, loss: 2.905342
# ----
#  one whows ofr some het's dow baby
# I let you things t'al teay
# What am just do ehon benn lind all of the mind is's tray
# And foof do hored eook
# wavl you things tr e my me fool thar somehow
# I let you
# ----
# iter 17900, loss: 3.188129
# ----
#  de of my door beosine of my door
# And all oow
# Prays sleps doophing ngre that lif ou for owht lit leres
# What am I doing w
# tam for sown jvenn else goes
# What am I doing without youing got a little wor
# ----
# iter 18000, loss: 3.294221
# ----
#   had
# As ir sorlsade of out am
# Nou things I've been looking for
# Have no hone
# No
# And all eor
# I's someone
# I'me tim our ou som things I've been I me mind now ho eone
# Who's just like you in where n
# ----
# iter 18100, loss: 3.240029
# ----
#  ve always been hethind of our own
# I'll tell you in wing t no
# Whathat am I'm I've me me goes
# Whatlit so krhout you
#
# Took for sers oves
# I've things It's you tim I I may
# What am I doing withing dow
# ----
# iter 18200, loss: 3.099961
# ----
#  fif's semeone whops you
# And all of the things I'm I may
# What am I doing without you
# And all of the things I've been looking for
# Have always been I guet if I'd find someone
# Who's just like you
#
# W
# ----
# iter 18300, loss: 2.950796
# ----
#  I've beene mahe thin wayounde if oret yout ne
# What am I doing without you
# And all of the things I've been hore
# I wing tine the thing nees
# When here outside of serls dere doing without you
# And all
# ----
# iter 18400, loss: 2.811775
# ----
#  doing without you
#
# Well it's feeling right now baby somehow now ha let lim I'm seaking for
# Have always been here outside of my door
# And all of the time I'm looking for something new
# What am I doin
# ----
# iter 18500, loss: 2.672856
# ----
#  u
#
# Well I guet liten ees
# What am junderlla little world of our own
# whe te fane been thas someleigst lou do
#
# We got a little time I'm looking for something new
# What am I doing without you
# And all
# ----
# iter 18600, loss: 2.548461
# ----
#  ind now homes no lee nome he's just like you things that no one else knows fell Har out litele wou got a little world of our own
# I'll tell you things that no one else knows
# that it's dre ghint am li
# ----
# iter 18700, loss: 2.424876
# ----
#  hat am I doing without you
# And all of the things I'm just real be somes gran I'm faveyo
# Ithit sometyings I've been looking for
# Have always been here outside of my door
# And all of the time I'm lookn
# ----
# iter 18800, loss: 2.317404
# ----
#   behind
# It plays on my mind now hoee noess nees doist ae tid thot no on esod foono lot you
# And fif our
# rell you things that no one else knows
# I let you in where no-one else goes ing rind of our so
# ----
# iter 18900, loss: 2.211553
# ----
#  where no-one els flohe ghat it's the I you come avo-one else goes
# What am I doing without you
#
# Took for grant of the gott ne eone fis sways been hooking for that it's true
# No buts or foobey nlwats
# ----
# iter 19000, loss: 2.119890
# ----
#  l happy
# When I leave you behind
# here no-one else go somes gokng for something new
# What am I doing without you
#
# Tout am I doing wn've beer hat ave nom outside of my door
# And all of the time I'm lo
# ----
# iter 19100, loss: 2.027835
# ----
#  elm lee
# Andoy
# I let you do
# thu time I wokng fomesof something new
# Whot am I doing withouthy wayou come around
# Yeae amaay nofes I'm orythings thitts me
# So lit sows
# What am I doing without you
# A
# ----
# iter 19200, loss: 1.950274
# ----
#  hout you
#
# Well I guess I'm raad in rle thon I lofe
# I leame you
#
# Funne fo's fookings I've been looking whent you
# And all of the things I've been looking for
# Have always been here outsing what look
# ----
# iter 19300, loss: 1.870583
# ----
#  l you things that no one else knows
# I let you in wihgt ne
# What am I doing without you
# And all of the time I'm looking for something newn
# Tvee ling uthitgl tI m ked
# As somntying new
# What serld of
# ----
# iter 19400, loss: 1.804885
# ----
#  oney
# What am I doing without you
# And all of the gnell
# Whathit's true
# No butt ar of the time I'm looking for something new
# What am I doing without you
# And all of the time rokn
# What am I doing wi
# ----
# iter 19500, loss: 1.734603
# ----
#  orld of our own
# I'll tell you things that no one else knows
# I whethinw of the wisgt nowlbe me the ring wine you
#
# Wenhing down
# And all of the things I've been looking for
# Have always been here out
# ----
# iter 19600, loss: 1.680482
# ----
#  that' own
# I'll that it's thee
# No
# I lot you do l
# tel gowt swapr nownd in wingo nown
# I let you behind
# It plays always dlepy
# What am I doing without you
#
# Took for grant beel I gutting without you
# ----
# iter 19700, loss: 1.619724
# ----
#  ou do l
# Well I guers of my domp it the time I'm hor something new It's feling wive you things I've been looking for
# Have always been he gat a little world of our own
# I'll tell you thingt noking with
# ----
# iter 19800, loss: 1.573484
# ----
#  en you
# And all of the time I's that aller's feel har ound find someone
# Who's just like you
#
# We fous Irle beat avee
# And fookind nowny
# It's feelint'se
# I'm fall now homeone
# Who wonl here outside o
# ----
# iter 19900, loss: 1.520093
# ----
# ...
# Weags that im
# ----
# iter 72600, loss: 0.391427
# ----
#  l happy
# When I leave you behind
# It plays on my mind now honey
# What am I doing without you
#
# Well it's feeling right now
# Praying that some how
# You will understand the way
# It's feeling right now b
# ----
# iter 72700, loss: 0.389146
# ----
#  else knows
# I let you in where no-one else goes
# What am I doing without you
# You make me feel happy
# When I leave you behind
# It plays on my mind now honey
# What am I doing without you
# And all of th
# ----
# iter 72800, loss: 0.385928
# ----
#  hout you
# And all of the things I've been looking for
# Have always been here outside of my door
# And all of the time I'm looking for somethings no-one else goes
# What am I doing without you
#
#
# What aw
# ----
# iter 72900, loss: 0.384009
# ----
#  l you things that no one else knows
# I let you in where no-one else goes
# What am I doing without you
# And all of the time I'm looking for someay
# Whot am eat am I doing without you
# And all of the th
# ----
# iter 73000, loss: 0.383065
# ----
#  oney
# What am I doing without you
# And alomy
# Werl out you
# And fif sometim tead thrr the time I'm looking for something new
# What am I doing without you
# And all of the things I've been looking for
#
# ----
# iter 73100, loss: 0.379430
# ----
#  orld of our own
# I'll tell you things that you behind
# It plays on my mind now honey
# What am I do irg t'mesoursod sitrs dee
# I'nl is that all of the we gat ay
# When I gont
# Whe's thet it als you
#
# We
# ----
# iter 73200, loss: 0.380761
# ----
#  I gous
# What am I doing without you
#
# Took for granted eooring for something new
# What am I doing without you
#
# Took thitps fave you nevle  foonbe of the welling fo ind oow you
# I's jven you behind
# I
# ----
# iter 73300, loss: 0.379738
# ----
#  ou do
#
# We got a little world of our own
# I'll tell you things that no one else knows
# I let you in where no-one else goet ind you
# And all of the time I'm looking for something new
# What am I doing w
# ----
# iter 73400, loss: 0.383321
# ----
#  en you come around
# Yeah that's what I found out honey
# What am I doing without you
# You make me feel happy
# When I leave you behind
# It plays on my mind now honey
# What am I doing without you
#
# Well
# ----
# iter 73500, loss: 0.381249
# ----
#  I'm  at's wr gre time I's justim tere beonn erou tim tea the deing for
# Have always you things that nooyt
# No lor ou mind alw of the time I'm looking for something new
# What am I you
#
# We got aTws feen
# ----
# iter 73600, loss: 0.380626
# ----
#  ou meay
# And all of the time I'm looking for something new
# What am I doing without you
#
# Took for may of time
# I loknd
# Whont yof hat I 'veay ishs wo litine I'm lit's that no one else knows
# I let yo
# ----
# iter 73700, loss: 0.377933
# ----
#  fe fous
# What am I doing without you things that no one else knows
# I let you in where I'wn doing without you
# You make me felling right now
# Praying that some how
# You will underlsof
# And all of the
# ----
# iter 73800, loss: 0.379152
# ----
#
# What am I doing without you
#
# Took for granted everything we had
# As if I'd find someone
# Who's just like you
#
# We got a little world of our own
# I'll tell you
# And gor f rides
# I'm I lithout you th
# ----
# iter 73900, loss: 0.375333
# ----
#  l it's you
#
# Funny how life can be so surprising
# I'm just realising what you do
#
# We got a little world of our own
# I'll tell you things that no one else knows
# I let you in where no-one else goes
# W
# ----
# iter 74000, loss: 0.373738
# ----
#  looking now hewn
# I leave you beene
# What am I doiig wone elou
# I me door
#
# Wen wrert no one
# It's feeling wof dou
#
# Welloin's feaying trat no one else goes
# What am where of been hing ting what you
#
# ----
# iter 74100, loss: 0.640668
# ----
#  one whoms you behind
# I mp mes rim I doing wot's thing new
# grat if our own
# I'll tell you things that some now yonl you ne litws gras that am I doing without you
# So let some howny
# What am I doing w
# ----
# iter 74200, loss: 1.243028
# ----
#
# And all of the time I'm looking for something new
# What am I doing without you
#
# Tooking dore how
# What am I doing without you
#
# Well it's feeling right now
# So let's do it right now baby so lit some
# ----
# iter 74300, loss: 1.444636
# ----
#  down
# There's always someone who saves me
# And girl it's dokn goks
#
# We got a little worltind out so pYave yown yoor
# And all of the things I've behing down
#
# Wen lo pre come I litthindou
# I leave you
# ----
# iter 74400, loss: 1.479210
# ----
#   here outside of mind is that am I doing without you
#
# Took for grat something new
# What am ou thot all of the time I'm looking for something new
# What am I doing without you
#
# Took for granted everyt
# ----
# iter 74500, loss: 1.429792
# ----
#  maybes
# When I'm falling down
# There no-one elways been here outside of my door
# And all of the time I'm looking for something new
# What am I doing without you
# And all of the things I've been looking
# ----
# iter 74600, loss: 1.353324
# ----
#  ing for
# Have always been here outside of my door
# And all of the time I'm looking for something new
# What am I doing wirltha
# I leave you sifl one
# I leave you girl out ho es I's find of mays fok
# Ha
# ----
# iter 74700, loss: 1.271323
# ----
#  at it's true
# No buts or me feel happy
# When I leave you behind
# It plays on my mind now hone els fealing right now baby somehow
# I won't let thay
# I'm falling down
# There's always someone who saves m
# ----
# iter 74800, loss: 1.195653
# ----
#  the things I've been looking for
# Have always been here outside of my door
# And all of the time I'm looking for something new
# What am I doing without you
#
# Well it's feeling right now
# So lers hettl
# ----
# iter 74900, loss: 1.123970
# ----
#  d is over
# And I swear that it's teu thing fown
# You mes I'm ready
# For settling down
# And fooling around is over
# And I swear that it's true
# No butsd dring neley
# What am I doing without you
#
# Took
# ----
# iter 75000, loss: 1.059101
# ----
#   without you
# And all of the things I've been looking for
# Have always been here outside of my door
# And all of the time I'm looking for something new
# What am I doing without you
# And all of the thin
# ----
# iter 75100, loss: 0.998056
# ----
#  g down
# And fooling around is over
# And I swear that it's true
# No buts or maybes
# When I'd fe my goes somes gras oundy
# When I'm falling down
# There's always someone who samesome
# For settling dow
# W
# ----
# iter 75200, loss: 0.943716
# ----
#  lse goes
# What am I doing without you
# And all of the things I've been looking for
# Have always been here outsine of my door
# And all of the time I'm looking for something new
# What am I doing without
# ----
# iter 75300, loss: 0.891423
# ----
#  tisim I doing without you
# And all of the things I've behind
# It lit's feeling right now
# So let's do is I'm falling down
# There's always someone whowny
# And if I'd find someone
# Who's just like you
#
# ----
# iter 75400, loss: 0.847029
# ----
#  let you in where no-one else goes
# What am I doing without you
# And all of the things I've been looking for
# Have always been here outside of my door
# And all of the time I'm looking for something new
# ----
# iter 75500, loss: 0.803523
# ----
#   without you
# You make me feel happy
# When I leave you behind
# It plays on my mind now honey
# What am I doing without you
#
# Well it's feeling right now ing withind you
# And all of the time I'm looking
# ----
# iter 75600, loss: 0.766131
# ----
#  hat no one else knows
# I let you in where no-one else goes
# What am I doing rlit ing right now
# So let's do it right now
# Praying that some how
# You will understand the way
# It's feeling right now
# So
# ----
# iter 75700, loss: 0.729811
# ----
#  hing new
# What am I doing without you
# You make me feel happy
# When I heany
#
# We got a little world of our own
# I'll tell you gor
# And fooling around is over
# And I swear that it's true
# No buts or ma
# ----
# iter 75800, loss: 0.697274
# ----
#  n
# I'll tell you things that no one else knows
# I let you in where no-one else goes
# What am I doing without you
# You make me feel happy
# When I leave yout ne elising that you things me
# And is of beh
# ----
# iter 75900, loss: 0.668712
# ----
#  ime I'm looking for something new
# What am I doing without you
# You make me feel happy
# When I leave you behind
# It plays on my mind now honey
# What am I doing without you
#
# Well it's feeling right no
# ----
# iter 76000, loss: 0.641554
# ----
#   a little world of our own
# I'll tell you things that no one else knows
# I let you in where no-one else goes
# What am I doing without you
# And all of the things I've been looking for
# Have always been
# ----
# iter 76100, loss: 0.618018
# ----
#  my dome hers it's you
#
#
# Took for something new
# What am I doing without you
#
# Took for grant you
# And avou
# And all of the time I'm looking for something new
# What am I doing without you
# And all of
# ----
# iter 76200, loss: 0.594856
# ----
#  t this slip away
#
# We got a little world ofr rere cour
# And all of the things I've been looking for
# Have always been here outside of my door
# And all of the time I'm looking for something new
# What a
# ----
# iter 76300, loss: 0.575952
# ----
#  ays been here outside of my door
# And all of the time I'm looking for something new
# What am I doing without you
#
# Well that it's tro end out you
# And wif hap y always of the time I'm looking for some
# ----
# iter 76400, loss: 0.556391
# ----
#
# So let's do it right now
# Praying that some how
# You will underst ne ees I'm looking nown
# I' m thittlno I'm falling down
# There's always someone who saves me
# And girl it's you
#
# Funny how life can
# ----
# iter 76500, loss: 0.540778
# ----
#  een loeeos owt came
# I lit senl of bee char sere
# And fifl aI m tide ofomy
# For serlind is that ho you come around
# Yeal aveo ithout he bee life ne
# I'm falling down
# There's always someone who saves
# ----
# iter 76600, loss: 0.524086
# ----
#  y
# It's feeling right at if's faeling right now
# So let's do it right now baby somehow
# I won't let this slip away
#
# We got a little world of our own
# I'll tell you things that no one else knows
# I le
# ----
# iter 76700, loss: 0.509321
# ----
#   all of the things I've been looking for
# Have always bee lot so let prising
# I'm just realising what you do
#
# We got a little world of our own
# I'll tell you things that you in eor ou my
# I leave you
# ----
# iter 76800, loss: 0.497156
# ----
#  ou will understand the way
# It's feeling right now baby somehow
# I won't let this slip away
#
# We got a little world of our own
# I'll tell you things that no one else knows
# I let you in where no-one e
# ----
# iter 76900, loss: 0.484736
# ----
#   I doing without you
#
# Well it's feeling right now
# So let's do it right now
# Praying that some how
# You will understand the wing whattim harl out you
#
# Well it's feeling right now baby somehow
# I won
# ----
# iter 77000, loss: 0.474610
# ----
#
# Praying that some how
# You will understend tho eat im the time I'm looking for something new
# What am I doing without you
# And all of the things I've been looking for
# Have always been here outsideli
# ----
# iter 77100, loss: 0.464018
# ----
#  no-one else goes
# What am I doing without you
#
# And tha ways been here outside of my door
# And all of the time I'm looking for something new yWd lit ling withind you
# And all of the time I'm looking f
# ----
# iter 77200, loss: 0.454366
# ----
#  So let's do it right now
# Praying that some how
# You will understand the way
# It's feeling right now
# So let's do it right now baby someho sount let this slip away
#
# We got a little world of our own
#
# ----
# iter 77300, loss: 0.445652
# ----
#  nows
# I let you in where no-one else goes
# What am I doing without you
#
# Well it's feeling right now baby somehow
# I won't let this slip away
#
# We got a little world of our own
# I'll tell you things t
# ----
# iter 77400, loss: 0.438139
# ----
#   it's feeling right now
# So let's do it right now baby somehow
# I won't let this slip away
#
# We got a little world of our own
# I'll tell you things that no one else knows
# I let you in where no-one el
# ----
# iter 77500, loss: 0.430584
# ----
#  things that no one else knows
# I let you in where no-one else goes
# What am I doing without you
#
# Took fifll I've been looking for
# Have always been here outside of my door
# And all of ting wono is oo
# ----
# iter 77600, loss: 0.424127
# ----
#   doing without you
# And all of the tine
# I've you git ame orr outsing new
# What am I doing without you
#
# Well it's feeling right now baby somehow
# I won't let thing down
# There's always someone who sa
# ----
# iter 77700, loss: 0.417245
# ----
#  f our own
# I'll tell you things that no one else knowndeiing for
# Hapl that it's true
# No buts or maybes
# When I'm falling down
# There's always someone who saves me
# And girl it's you
#
# Funny how liti
# ----
# iter 77800, loss: 0.411932
# ----
#   something new
# What am I doing without you
# And all of the things I've been looking for
# Have always been here outside of my door
# And all of the time I'm looking for some here thnt lear thind
# Wenn
# ----
# iter 77900, loss: 0.404695
# ----
#
# Have always someone who saves me
# And girl it's you
#
# Funny how life can be so surprising
# I'm just realising what you do
#
# We got a little world for out am beat you behne
# I'll tell you bell you thi
# ----
# iter 78000, loss: 0.401384
# ----
#   the time I'm looking for something new
# What am I doing without you
#
# Took for granted everything we had
# As if rof the will understand the way
# It's feeling right now
# So let's do it right now
# Pray
# ----
# iter 78100, loss: 0.394976
# ----
#  one
# Who's just like you
#
# We got a little world of our own
# I'll tell you thind thin where no-one else kisw doing without you
#
# Took for granted every
# What am I doing without you
# And all of the thi
# ----
# iter 78200, loss: 0.392150
# ----
#  de of my door
# And all of the time I'm looking for something new
# What am I doing without you
# And all of the things I've been looking for
# Have always yow nYell that it's true
# No buts or maybes
# Whe
# ----
# iter 78300, loss: 0.386532
# ----
#  thu tI doing without you
# You make me feel happy
# When I leave you behind
# It plays on my me behing without you
#
# Took for granted everything we had
# As if I'd find someone
# Who's just like you
#
# We g
# ----
# iter 78400, loss: 0.384192
# ----
#  ve always been here outside of my door
# And all of the time I'm looking for something new
# What am I doing without you things that nooyt you
# And all of the time I'm looking for something new
# What am
# ----
# iter 78500, loss: 0.379161
# ----
#  for granted everything we had
# As if I'd find someone
# Who's just like you
#
# We got a little world of our own
# I'll tell you timl I've been looking for
# Have always been here outside of my door
# And a
# ----
# iter 78600, loss: 0.377098
# ----
#  I've been looking for
# Have always been here outside of my door
# And all of the time I'm looking for sHanl
# What am I doing without you
#
# Took fo ll I'm looeid ou behat al onegy
# And all of the time I
# ----
# iter 78700, loss: 0.372712
# ----
#  doing without you
# And all of the things I've been looking for
# Have always been here seall
# I've beon leale what am meke thot it's true
# No buts or maybes
# When I'm falling down
# There's always someo
# ----
# iter 78800, loss: 0.370904
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-ed8175e4bb68> in <module>()
#      18
#      19   # forward seq_length characters through the net and fetch gradient
# ---> 20   loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
#      21   smooth_loss = smooth_loss * 0.999 + loss * 0.001
#      22   if n % 100 == 0: print 'iter %d, loss: %f' % (n, smooth_loss) # print progress
#
# <ipython-input-13-d0d392d79d3b> in lossFun(inputs, targets, hprev)
#      12     xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
#      13     xs[t][inputs[t]] = 1
# ---> 14     hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
#      15     ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
#      16     ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
#
# KeyboardInterrupt:

# %%
inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]

# %%
inputs
# Out:
# [1,
#  28,
#  27,
#  3,
#  27,
#  28,
#  17,
#  1,
#  17,
#  26,
#  30,
#  17,
#  1,
#  19,
#  27,
#  17,
#  30,
#  1,
#  0,
#  12,
#  22,
#  14,
#  33,
#  1,
#  14]

# %%
targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

# %%
targets
# Out:
# [28,
#  27,
#  3,
#  27,
#  28,
#  17,
#  1,
#  17,
#  26,
#  30,
#  17,
#  1,
#  19,
#  27,
#  17,
#  30,
#  1,
#  0,
#  12,
#  22,
#  14,
#  33,
#  1,
#  14,
#  25]
